# %% [markdown]
# # Assignment: Information Retrieval (IR)

# %% [markdown]
# ## Preparations
# * Put all your imports, and path constants in the next cells

# %%
# !pip install whoosh
# !pip install pytrec_eval
# !pip install wget
# Out:
# Requirement already satisfied: whoosh in /usr/local/lib/python3.7/dist-packages (2.7.4)
# Requirement already satisfied: pytrec_eval in /usr/local/lib/python3.7/dist-packages (0.5)
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (3.2)

# %%
import wget
wget.download("https://github.com/MIE1513HS-2022/course-datasets/raw/main/government.zip", "government.zip")
# Out:
# 'government (4).zip'

# %%
# !unzip government.zip
# Out:
# Archive:  government.zip
# replace government/topics-with-full-descriptions.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: None

# %%
# imports
# Put all your imports here
from whoosh import index, writing, qparser,scoring
from whoosh.fields import Schema, TEXT, KEYWORD, ID, STORED
from whoosh.analysis import *
from whoosh.qparser import QueryParser
import os.path
from pathlib import Path
import tempfile
import subprocess
import pytrec_eval
import wget
import abc
from abc import abstractmethod
from whoosh.analysis import Filter
from whoosh.writing import BufferedWriter
import nltk
from nltk.stem import *
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
class IRSystem(metaclass=abc.ABCMeta):
    """
    Abstract class which is inherited by other IR system
    """

    def __init__(self, data_dir):
        # DON'T change the following names,topic_file, qrels_file, document_dir, file_list
        self.topic_file = os.path.join(data_dir, "gov.topics")
        self.qrels_file = os.path.join(data_dir, "gov.qrels")
        self.document_dir = os.path.join(data_dir, "documents") 
        self.file_list = [str(filePath) for filePath in Path(self.document_dir).glob("**/*") if filePath.is_file()]

        self.create_index()
        self.add_files()
        self.create_parser_searcher()

    @abstractmethod
    def create_index(self):
        pass

    @abstractmethod
    def add_files(self):
        pass

    @abstractmethod
    def create_parser_searcher(self):
        pass

    @abstractmethod
    def perform_search(self, topic_phrase):
        pass

    @staticmethod
    def post_process_score(score):
        return score

    @staticmethod
    def print_trec_eval_result(results):
        if not results:
            print('empty results')
            return

        def print_line(name, scope, num):
            print('{:25s}{:8s}{:.4f}'.format(name, scope, num))

        for query_id, query_measures in results.items():
            for measure, value in query_measures.items():
                if measure == "runid":
                    continue
                print_line(measure, query_id, value)

        for measure in query_measures.keys():
            if measure == "runid":
                continue
            print_line(
                measure,
                'all',
                pytrec_eval.compute_aggregated_measure(
                    measure,
                    [query_measures[measure]
                     for query_measures in results.values()]))
            
    def print_rel_name(self, q_id):
        with open(self.topic_file, "r") as tf:
            topics = tf.read().splitlines()
        for topic in topics:
            topic_id, topic_phrase = tuple(topic.split(" ", 1))
            if topic_id == q_id:
                print("---------------------------Topic_id and Topic_phrase----------------------------------")
                print(topic_id, topic_phrase)
                 # get search result
                topic_results = self.perform_search(topic_phrase)
                print("---------------------------Return documents----------------------------------")
                for (docnum, result) in enumerate(topic_results):
                    score = topic_results.score(docnum)
                    score = self.post_process_score(score)
                    print("%s Q0 %s %d %lf test" % (topic_id, os.path.basename(result["file_path"]), docnum, score))
                print("---------------------------Relevant documents----------------------------------")
                with open(self.qrels_file, 'r') as f_qrel:
                    qrels = f_qrel.readlines()
                    for i in qrels:
                        qid, _, doc, rel = i.rstrip().split(" ")
                        if qid == q_id and rel == "1":
                            print(i.rstrip())

    def py_trec_eval(self):
        # Load topic file - a list of topics(search phrases) used for evalutation
        with open(self.topic_file, "r") as tf:
            topics = tf.read().splitlines()

            # create an output file to which we'll write our results
        temp_output_file = tempfile.mkstemp()[1]
        with open(temp_output_file, "w") as outputTRECFile:
            # for each evaluated topic:
            # build a query and record the results in the file in TREC_EVAL format
            for topic in topics:
                topic_id, topic_phrase = tuple(topic.split(" ", 1))
                # get search result
                topic_results = self.perform_search(topic_phrase)
                # format the result
                for (docnum, result) in enumerate(topic_results):
                    score = topic_results.score(docnum)
                    outputTRECFile.write(
                        "%s Q0 %s %d %lf test\n" % (topic_id, os.path.basename(result["file_path"]), docnum, score))

        with open(self.qrels_file, 'r') as f_qrel:
            qrel = pytrec_eval.parse_qrel(f_qrel)

        with open(temp_output_file, 'r') as f_run:
            run = pytrec_eval.parse_run(f_run)

        evaluator = pytrec_eval.RelevanceEvaluator(
            qrel, pytrec_eval.supported_measures)

        results = evaluator.evaluate(run)

        self.print_trec_eval_result(results)

# %%
# Dont change this! Use it as-is in your code
# This filter will run for both the index and the query
class CustomFilter(Filter):
    is_morph = True
    def __init__(self, filterFunc, *args, **kwargs):
        self.customFilter = filterFunc
        self.args = args
        self.kwargs = kwargs
    def __eq__(self):
        return (other
                and self.__class__ is other.__class__)
    def __call__(self, tokens):
        for t in tokens:
            if t.mode == 'query': # if called by query parser
                t.text = self.customFilter(t.text, *self.args, **self.kwargs)
                yield t
            else: # == 'index' if called by indexer
                t.text = self.customFilter(t.text, *self.args, **self.kwargs)
                yield t

# %% [markdown]
# ## Question 1
# Provide your text answers in the following two markdown cells

# %% [markdown]
# ### Q1 (a): Provide answer to Q1 (a) here [markdown cell]
# iprec_at_recall_1.00 all

# %% [markdown]
# ### Q1 (b): Provide answer to Q1 (b) here [markdown cell]
# iprec_at_recall_1.00 means Precision Averages at 1.00 recall, which meausres a score of once all the relevant documents are included in the search results, how many of those are actually relevant and how many are not relevant as precision is true positive out of all the positive predictions. For a government website search, the person who is searching likely wants a complete set of information regarding the search topics, not just some information. Therefore, the person will likely read all the top relevant documents in case the other ones contain some edge case regarding the topic he/she is trying to search too. Thus, it is important that there are as few irrelevant documents as possible until the person finishes reading through all the relevant documents. Because if the person reads an irrelevant document, he/she will assume the results after that one is also equally or less relevant and will likely stop reading at that point.

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Q2 (a): Write your code below

# %% [markdown]
# **1. The auto-grader will extract and use the following variables, DON'T change the their names:**
#
#       self.topic_file
#       self.qrels_file
#       self.document_dir
#       self.file_list
#       self.index_sys
#       self.query_parser
#       self.searcher
#
#
#
# **2. DON'T change the names of the already defined funtions**
# **3. DON'T change the py_trec_eval function**
# **4. DON'T change the class names including CustomFilter, IRSystem, IRQ2, IRQ3, IRQ4**
# **5. DON'T change the CustomFilter class and DON'T create any new custom filter class that is used to define Whoosh schema**

# %%
class IRQ2(IRSystem):
    def create_index(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Please update self.index_sys which should have type whoosh.index.FileIndex
        """
        # DON't change the name of 'index_sys'
        self.schema = Schema(file_path = ID(stored=True),
                             file_content = TEXT(analyzer = RegexTokenizer()))
        self.index_sys = index.create_in(tempfile.mkdtemp(), self.schema)

    def add_files(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Add buffer to self.index_sys
        """
        # open writer
        writer = writing.BufferedWriter(self.index_sys, period=None, limit=1000)

        try:
            # write each file to index
            for docNum, filePath in enumerate(self.file_list):
                with open(filePath, "r", encoding="utf-8") as f:
                    fileContent = f.read()
                    writer.add_document(file_path = filePath,
                                        file_content = fileContent)

                    # print status every 1000 documents
                    if (docNum+1) % 1000 == 0:
                        print("already indexed:", docNum+1)
            print("done indexing.")

        finally:
            # close the index
            writer.close()

    def create_parser_searcher(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Please update self.query_parser and self.searcher which should have type whoosh.qparser.default.QueryParser and whoosh.searching.Searcher respectively 
        """
         # DON't change the names of 'query_parser' and 'searcher'
        self.query_parser = QueryParser("file_content", schema=self.schema)
        self.searcher = self.index_sys.searcher()

    def perform_search(self, topic_phrase):
        """
        INPUT:
            topic_phrase: string
        OUTPUT:
            topic_results: whoosh.searching.Results
        
        NOTE: Utilize self.query_parser and self.searcher to calculate the result for topic_phrase
        """
        query = self.query_parser.parse(topic_phrase)
        topic_results = self.searcher.search(query, limit=None)
        return topic_results

# %%
q2 = IRQ2("government")
# Out:
# already indexed: 1000
# already indexed: 2000
# already indexed: 3000
# already indexed: 4000
# done indexing.

# %%
q2.py_trec_eval()
# Out:
# num_q                    1       1.0000
# num_ret                  1       1.0000
# num_rel                  1       5.0000
# num_rel_ret              1       0.0000
# map                      1       0.0000
# gm_map                   1       -11.5129
# Rprec                    1       0.0000
# bpref                    1       0.0000
# recip_rank               1       0.0000
# iprec_at_recall_0.00     1       0.0000
# iprec_at_recall_0.10     1       0.0000
# iprec_at_recall_0.20     1       0.0000
# iprec_at_recall_0.30     1       0.0000
# iprec_at_recall_0.40     1       0.0000
# iprec_at_recall_0.50     1       0.0000
# iprec_at_recall_0.60     1       0.0000
# iprec_at_recall_0.70     1       0.0000
# iprec_at_recall_0.80     1       0.0000
# iprec_at_recall_0.90     1       0.0000
# iprec_at_recall_1.00     1       0.0000
# P_5                      1       0.0000
# P_10                     1       0.0000
# P_15                     1       0.0000
# P_20                     1       0.0000
# P_30                     1       0.0000
# P_100                    1       0.0000
# P_200                    1       0.0000
# P_500                    1       0.0000
# P_1000                   1       0.0000
# relstring                1       0.0000
# recall_5                 1       0.0000
# recall_10                1       0.0000
# recall_15                1       0.0000
# recall_20                1       0.0000
# recall_30                1       0.0000
# recall_100               1       0.0000
# recall_200               1       0.0000
# recall_500               1       0.0000
# recall_1000              1       0.0000
# infAP                    1       0.0000
# gm_bpref                 1       -11.5129
# Rprec_mult_0.20          1       0.0000
# Rprec_mult_0.40          1       0.0000
# Rprec_mult_0.60          1       0.0000
# Rprec_mult_0.80          1       0.0000
# Rprec_mult_1.00          1       0.0000
# Rprec_mult_1.20          1       0.0000
# Rprec_mult_1.40          1       0.0000
# Rprec_mult_1.60          1       0.0000
# ndcg_cut_15              7       0.0000
# ndcg_cut_20              7       0.0000
# ndcg_cut_30              7       0.0000
# ndcg_cut_100             7       0.0000
# ndcg_cut_200             7       0.0000
# ndcg_cut_500             7       0.0000
# ndcg_cut_1000            7       0.0000
# map_cut_5                7       0.0000
# map_cut_10               7       0.0000
# map_cut_15               7       0.0000
# map_cut_20               7       0.0000
# map_cut_30               7       0.0000
# map_cut_100              7       0.0000
# map_cut_200              7       0.0000
# map_cut_500              7       0.0000
# map_cut_1000             7       0.0000
# relative_P_5             7       0.0000
# relative_P_10            7       0.0000
# relative_P_15            7       0.0000
# relative_P_20            7       0.0000
# relative_P_30            7       0.0000
# relative_P_100           7       0.0000
# relative_P_200           7       0.0000
# relative_P_500           7       0.0000
# relative_P_1000          7       0.0000
# success_1                7       0.0000
# success_5                7       0.0000
# success_10               7       0.0000
# set_P                    7       0.0000
# set_relative_P           7       0.0000
# set_recall               7       0.0000
# set_map                  7       0.0000
# set_F                    7       0.0000
# num_nonrel_judged_ret    7       5.0000
# num_q                    9       1.0000
# num_ret                  9       2.0000
# num_rel                  9       1.0000
# num_rel_ret              9       0.0000
# map                      9       0.0000
# gm_map                   9       -11.5129
# Rprec                    9       0.0000
# bpref                    9       0.0000
# recip_rank               9       0.0000
# iprec_at_recall_0.00     9       0.0000
# iprec_at_recall_0.10     9       0.0000
# iprec_at_recall_0.20     9       0.0000
# iprec_at_recall_0.30     9       0.0000
# iprec_at_recall_0.40     9       0.0000
# iprec_at_recall_0.50     9       0.0000
# iprec_at_recall_0.60     9       0.0000
# iprec_at_recall_0.70     9       0.0000
# iprec_at_recall_0.80     9       0.0000
# iprec_at_recall_0.90     9       0.0000
# iprec_at_recall_1.00     9       0.0000
# P_5                      9       0.0000
# P_10                     9       0.0000
# P_15                     9       0.0000
# P_20                     9       0.0000
# P_30                     9       0.0000
# P_100                    9       0.0000
# P_200                    9       0.0000
# P_500                    9       0.0000
# P_1000                   9       0.0000
# relstring                9       0.0000
# recall_5                 9       0.0000
# recall_10                9       0.0000
# recall_15                9       0.0000
# recall_20                9       0.0000
# recall_30                9       0.0000
# recall_100               9       0.0000
# recall_200               9       0.0000
# recall_500               9       0.0000
# recall_1000              9       0.0000
# infAP                    9       0.0000
# gm_bpref                 9       -11.5129
# Rprec_mult_0.20          9       0.0000
# Rprec_mult_0.40          9       0.0000
# Rprec_mult_0.60          9       0.0000
# Rprec_mult_0.80          9       0.0000
# Rprec_mult_1.00          9       0.0000
# Rprec_mult_1.20          9       0.0000
# Rprec_mult_1.40          9       0.0000
# Rprec_mult_1.60          9       0.0000
# Rprec_mult_1.80          9       0.0000
# Rprec_mult_2.00          9       0.0000
# utility                  9       -2.0000
# 11pt_avg                 9       0.0000
# binG                     9       0.0000
# G                        9       0.0000
# ndcg                     9       0.0000
# ndcg_rel                 9       0.0000
# Rndcg                    9       0.0000
# ndcg_cut_5               9       0.0000
# ndcg_cut_10              9       0.0000
# ndcg_cut_15              9       0.0000
# ndcg_cut_20              9       0.0000
# ndcg_cut_30              9       0.0000
# ndcg_cut_100             9       0.0000
# ndcg_cut_200             9       0.0000
# ndcg_cut_500             9       0.0000
# ndcg_cut_1000            9       0.0000
# map_cut_5                9       0.0000
# map_cut_10               9       0.0000
# map_cut_15               9       0.0000
# map_cut_20               9       0.0000
# map_cut_30               9       0.0000
# map_cut_100              9       0.0000
# map_cut_200              9       0.0000
# map_cut_500              9       0.0000
# map_cut_1000             9       0.0000
# relative_P_5             9       0.0000
# relative_P_10            9       0.0000
# relative_P_15            9       0.0000
# relative_P_20            9       0.0000
# relative_P_30            9       0.0000
# relative_P_100           9       0.0000
# relative_P_200           9       0.0000
# relative_P_500           9       0.0000
# relative_P_1000          9       0.0000
# success_1                9       0.0000
# success_5                9       0.0000
# success_10               9       0.0000
# set_P                    9       0.0000
# set_relative_P           9       0.0000
# set_recall               9       0.0000
# set_map                  9       0.0000
# set_F                    9       0.0000
# num_nonrel_judged_ret    9       2.0000
# num_q                    10      1.0000
# num_ret                  10      16.0000
# num_rel                  10      1.0000
# num_rel_ret              10      1.0000
# map                      10      0.1667
# gm_map                   10      -1.7918
# Rprec                    10      0.0000
# bpref                    10      0.0000
# recip_rank               10      0.1667
# iprec_at_recall_0.00     10      0.1667
# iprec_at_recall_0.10     10      0.1667
# iprec_at_recall_0.20     10      0.1667
# iprec_at_recall_0.30     10      0.1667
# iprec_at_recall_0.40     10      0.1667
# iprec_at_recall_0.50     10      0.1667
# iprec_at_recall_0.60     10      0.1667
# iprec_at_recall_0.70     10      0.1667
# iprec_at_recall_0.80     10      0.1667
# iprec_at_recall_0.90     10      0.1667
# iprec_at_recall_1.00     10      0.1667
# P_5                      10      0.0000
# P_10                     10      0.1000
# P_15                     10      0.0667
# P_20                     10      0.0500
# P_30                     10      0.0333
# P_100                    10      0.0100
# P_200                    10      0.0050
# P_500                    10      0.0020
# P_1000                   10      0.0010
# relstring                10      0.0000
# recall_5                 10      0.0000
# recall_10                10      1.0000
# recall_15                10      1.0000
# recall_20                10      1.0000
# recall_30                10      1.0000
# recall_100               10      1.0000
# recall_200               10      1.0000
# recall_500               10      1.0000
# recall_1000              10      1.0000
# infAP                    10      0.1667
# gm_bpref                 10      -11.5129
# Rprec_mult_0.20          10      0.0000
# Rprec_mult_0.40          10      0.0000
# Rprec_mult_0.60          10      0.0000
# Rprec_mult_0.80          10      0.0000
# Rprec_mult_1.00          10      0.0000
# Rprec_mult_1.20          10      0.0000
# Rprec_mult_1.40          10      0.0000
# Rprec_mult_1.60          10      0.0000
# Rprec_mult_1.80          10      0.0000
# Rprec_mult_2.00          10      0.0000
# utility                  10      -14.0000
# 11pt_avg                 10      0.1667
# binG                     10      0.3562
# G                        10      0.3562
# ndcg                     10      0.3562
# ndcg_rel                 10      0.3562
# Rndcg                    10      0.1781
# ndcg_cut_5               10      0.0000
# ndcg_cut_10              10      0.3562
# ndcg_cut_15              10      0.3562
# ndcg_cut_20              10      0.3562
# ndcg_cut_30              10      0.3562
# ndcg_cut_100             10      0.3562
# ndcg_cut_200             10      0.3562
# ndcg_cut_500             10      0.3562
# ndcg_cut_1000            10      0.3562
# map_cut_5                10      0.0000
# map_cut_10               10      0.1667
# map_cut_15               10      0.1667
# map_cut_20               10      0.1667
# map_cut_30               10      0.1667
# map_cut_100              10      0.1667
# map_cut_200              10      0.1667
# map_cut_500              10      0.1667
# map_cut_1000             10      0.1667
# relative_P_5             10      0.0000
# relative_P_10            10      1.0000
# relative_P_15            10      1.0000
# relative_P_20            10      1.0000
# relative_P_30            10      1.0000
# relative_P_100           10      1.0000
# relative_P_200           10      1.0000
# relative_P_500           10      1.0000
# relative_P_1000          10      1.0000
# success_1                10      0.0000
# success_5                10      0.0000
# success_10               10      1.0000
# set_P                    10      0.0625
# set_relative_P           10      1.0000
# set_recall               10      1.0000
# set_map                  10      0.0625
# set_F                    10      0.1176
# num_nonrel_judged_ret    10      10.0000
# num_q                    14      1.0000
# num_ret                  14      7.0000
# num_rel                  14      1.0000
# num_rel_ret              14      1.0000
# map                      14      0.2500
# gm_map                   14      -1.3863
# Rprec                    14      0.0000
# bpref                    14      0.0000
# recip_rank               14      0.2500
# iprec_at_recall_0.00     14      0.2500
# iprec_at_recall_0.10     14      0.2500
# iprec_at_recall_0.20     14      0.2500
# iprec_at_recall_0.30     14      0.2500
# iprec_at_recall_0.40     14      0.2500
# iprec_at_recall_0.50     14      0.2500
# iprec_at_recall_0.60     14      0.2500
# iprec_at_recall_0.70     14      0.2500
# iprec_at_recall_0.80     14      0.2500
# iprec_at_recall_0.90     14      0.2500
# iprec_at_recall_1.00     14      0.2500
# P_5                      14      0.2000
# P_10                     14      0.1000
# P_15                     14      0.0667
# P_20                     14      0.0500
# P_30                     14      0.0333
# P_100                    14      0.0100
# P_200                    14      0.0050
# P_500                    14      0.0020
# P_1000                   14      0.0010
# relstring                14      0.0000
# recall_5                 14      1.0000
# recall_10                14      1.0000
# recall_15                14      1.0000
# recall_20                14      1.0000
# recall_30                14      1.0000
# recall_100               14      1.0000
# recall_200               14      1.0000
# recall_500               14      1.0000
# recall_1000              14      1.0000
# infAP                    14      0.2500
# gm_bpref                 14      -11.5129
# Rprec_mult_0.20          14      0.0000
# Rprec_mult_0.40          14      0.0000
# Rprec_mult_0.60          14      0.0000
# Rprec_mult_0.80          14      0.0000
# Rprec_mult_1.00          14      0.0000
# Rprec_mult_1.20          14      0.0000
# Rprec_mult_1.40          14      0.0000
# Rprec_mult_1.60          14      0.0000
# Rprec_mult_1.80          14      0.0000
# Rprec_mult_2.00          14      0.0000
# utility                  14      -5.0000
# 11pt_avg                 14      0.2500
# binG                     14      0.4307
# G                        14      0.4307
# ndcg                     14      0.4307
# ndcg_rel                 14      0.4307
# Rndcg                    14      0.2153
# ndcg_cut_5               14      0.4307
# ndcg_cut_10              14      0.4307
# ndcg_cut_15              14      0.4307
# ndcg_cut_20              14      0.4307
# ndcg_cut_30              14      0.4307
# ndcg_cut_100             14      0.4307
# ndcg_cut_200             14      0.4307
# ndcg_cut_500             14      0.4307
# ndcg_cut_1000            14      0.4307
# map_cut_1000             22      0.2000
# relative_P_5             22      1.0000
# relative_P_10            22      1.0000
# relative_P_15            22      1.0000
# relative_P_20            22      1.0000
# relative_P_30            22      1.0000
# relative_P_100           22      1.0000
# relative_P_200           22      1.0000
# relative_P_500           22      1.0000
# relative_P_1000          22      1.0000
# success_1                22      0.0000
# success_5                22      1.0000
# success_10               22      1.0000
# set_P                    22      0.0588
# set_relative_P           22      1.0000
# set_recall               22      1.0000
# set_map                  22      0.0588
# set_F                    22      0.1111
# num_nonrel_judged_ret    22      15.0000
# num_q                    24      1.0000
# num_ret                  24      7.0000
# num_rel                  24      1.0000
# num_rel_ret              24      1.0000
# map                      24      1.0000
# gm_map                   24      0.0000
# Rprec                    24      1.0000
# bpref                    24      1.0000
# recip_rank               24      1.0000
# iprec_at_recall_0.00     24      1.0000
# iprec_at_recall_0.10     24      1.0000
# iprec_at_recall_0.20     24      1.0000
# iprec_at_recall_0.30     24      1.0000
# iprec_at_recall_0.40     24      1.0000
# iprec_at_recall_0.50     24      1.0000
# iprec_at_recall_0.60     24      1.0000
# iprec_at_recall_0.70     24      1.0000
# iprec_at_recall_0.80     24      1.0000
# iprec_at_recall_0.90     24      1.0000
# iprec_at_recall_1.00     24      1.0000
# P_5                      24      0.2000
# P_10                     24      0.1000
# P_15                     24      0.0667
# P_20                     24      0.0500
# P_30                     24      0.0333
# P_100                    24      0.0100
# P_200                    24      0.0050
# P_500                    24      0.0020
# P_1000                   24      0.0010
# relstring                24      0.0000
# recall_5                 24      1.0000
# recall_10                24      1.0000
# recall_15                24      1.0000
# recall_20                24      1.0000
# recall_30                24      1.0000
# recall_100               24      1.0000
# recall_200               24      1.0000
# recall_500               24      1.0000
# recall_1000              24      1.0000
# infAP                    24      1.0000
# gm_bpref                 24      0.0000
# Rprec_mult_0.20          24      1.0000
# Rprec_mult_0.40          24      1.0000
# Rprec_mult_0.60          24      1.0000
# Rprec_mult_0.80          24      1.0000
# Rprec_mult_1.00          24      1.0000
# Rprec_mult_1.20          24      0.5000
# Rprec_mult_1.40          24      0.5000
# Rprec_mult_1.60          24      0.5000
# Rprec_mult_1.80          24      0.5000
# Rprec_mult_2.00          24      0.5000
# utility                  24      -5.0000
# 11pt_avg                 24      1.0000
# binG                     24      1.0000
# G                        24      1.0000
# ndcg                     24      1.0000
# ndcg_rel                 24      1.0000
# Rndcg                    24      1.0000
# ndcg_cut_5               24      1.0000
# ndcg_cut_10              24      1.0000
# ndcg_cut_15              24      1.0000
# ndcg_cut_20              24      1.0000
# ndcg_cut_30              24      1.0000
# ndcg_cut_100             24      1.0000
# ndcg_cut_200             24      1.0000
# ndcg_cut_500             24      1.0000
# ndcg_cut_1000            24      1.0000
# map_cut_5                24      1.0000
# map_cut_10               24      1.0000
# map_cut_15               24      1.0000
# map_cut_20               24      1.0000
# map_cut_30               24      1.0000
# map_cut_100              24      1.0000
# map_cut_200              24      1.0000
# map_cut_500              24      1.0000
# map_cut_1000             24      1.0000
# relative_P_5             24      1.0000
# relative_P_10            24      1.0000
# relative_P_15            24      1.0000
# relative_P_20            24      1.0000
# relative_P_30            24      1.0000
# relative_P_100           24      1.0000
# relative_P_200           24      1.0000
# relative_P_500           24      1.0000
# relative_P_1000          24      1.0000
# success_1                24      1.0000
# success_5                24      1.0000
# success_10               24      1.0000
# set_P                    24      0.1429
# set_relative_P           24      1.0000
# set_recall               24      1.0000
# set_map                  24      0.1429
# set_F                    24      0.2500
# num_nonrel_judged_ret    24      6.0000
# num_q                    26      1.0000
# num_ret                  26      25.0000
# num_rel                  26      3.0000
# num_rel_ret              26      1.0000
# map                      26      0.1111
# gm_map                   26      -2.1972
# Rprec                    26      0.3333
# bpref                    26      0.1111
# recip_rank               26      0.3333
# iprec_at_recall_0.00     26      0.3333
# iprec_at_recall_0.10     26      0.3333
# iprec_at_recall_0.20     26      0.3333
# iprec_at_recall_0.30     26      0.3333
# iprec_at_recall_0.40     26      0.0000
# iprec_at_recall_0.50     26      0.0000
# iprec_at_recall_0.60     26      0.0000
# iprec_at_recall_0.70     26      0.0000
# iprec_at_recall_0.80     26      0.0000
# iprec_at_recall_0.90     26      0.0000
# iprec_at_recall_1.00     26      0.0000
# P_5                      26      0.2000
# P_10                     26      0.1000
# P_15                     26      0.0667
# P_20                     26      0.0500
# P_30                     26      0.0333
# P_100                    26      0.0100
# P_200                    26      0.0050
# P_500                    26      0.0020
# P_1000                   26      0.0010
# relstring                26      0.0000
# recall_5                 26      0.3333
# recall_10                26      0.3333
# recall_15                26      0.3333
# recall_20                26      0.3333
# recall_30                26      0.3333
# recall_100               26      0.3333
# recall_200               26      0.3333
# recall_500               26      0.3333
# recall_1000              26      0.3333
# infAP                    26      0.1111
# gm_bpref                 26      -2.1972
# Rprec_mult_0.20          26      0.0000
# Rprec_mult_0.40          26      0.0000
# Rprec_mult_0.60          26      0.0000
# Rprec_mult_0.80          26      0.3333
# Rprec_mult_1.00          26      0.3333
# Rprec_mult_1.20          26      0.2500
# Rprec_mult_1.40          26      0.2000
# Rprec_mult_1.60          26      0.2000
# Rprec_mult_1.80          26      0.1667
# Rprec_mult_2.00          26      0.1667
# utility                  26      -23.0000
# 11pt_avg                 26      0.1212
# binG                     26      0.1667
# G                        26      0.1667
# ndcg                     26      0.2346
# ndcg_rel                 26      0.2346
# Rndcg                    26      0.2346
# ndcg_cut_5               26      0.2346
# ndcg_cut_10              26      0.2346
# ndcg_cut_15              26      0.2346
# ndcg_cut_20              26      0.2346
# ndcg_cut_30              26      0.2346
# ndcg_cut_100             26      0.2346
# ndcg_cut_200             26      0.2346
# ndcg_cut_500             26      0.2346
# ndcg_cut_1000            26      0.2346
# map_cut_5                26      0.1111
# map_cut_10               26      0.1111
# map_cut_15               26      0.1111
# map_cut_20               26      0.1111
# map_cut_30               26      0.1111
# map_cut_100              26      0.1111
# map_cut_200              26      0.1111
# map_cut_500              26      0.1111
# map_cut_1000             26      0.1111
# relative_P_5             26      0.3333
# relative_P_10            26      0.3333
# relative_P_15            26      0.3333
# relative_P_20            26      0.3333
# relative_P_30            26      0.3333
# relative_P_100           26      0.3333
# relative_P_200           26      0.3333
# relative_P_500           26      0.3333
# relative_P_1000          26      0.3333
# success_1                26      0.0000
# success_5                26      1.0000
# success_10               26      1.0000
# set_P                    26      0.0400
# set_relative_P           26      0.3333
# set_recall               26      0.3333
# set_map                  26      0.0133
# set_F                    26      0.0714
# num_nonrel_judged_ret    26      22.0000
# num_q                    28      1.0000
# num_ret                  28      22.0000
# num_rel                  28      2.0000
# num_rel_ret              28      0.0000
# map                      28      0.0000
# gm_map                   28      -11.5129
# Rprec                    28      0.0000
# bpref                    28      0.0000
# recip_rank               28      0.0000
# iprec_at_recall_0.00     28      0.0000
# iprec_at_recall_0.10     28      0.0000
# iprec_at_recall_0.20     28      0.0000
# iprec_at_recall_0.30     28      0.0000
# iprec_at_recall_0.40     28      0.0000
# iprec_at_recall_0.50     28      0.0000
# iprec_at_recall_0.60     28      0.0000
# iprec_at_recall_0.70     28      0.0000
# iprec_at_recall_0.80     28      0.0000
# iprec_at_recall_0.90     28      0.0000
# iprec_at_recall_1.00     28      0.0000
# P_5                      28      0.0000
# P_10                     28      0.0000
# P_15                     28      0.0000
# P_20                     28      0.0000
# P_30                     28      0.0000
# P_100                    28      0.0000
# P_200                    28      0.0000
# P_500                    28      0.0000
# P_1000                   28      0.0000
# relstring                28      0.0000
# recall_5                 28      0.0000
# recall_10                28      0.0000
# recall_15                28      0.0000
# recall_20                28      0.0000
# recall_30                28      0.0000
# recall_100               28      0.0000
# recall_200               28      0.0000
# recall_500               28      0.0000
# recall_1000              28      0.0000
# infAP                    28      0.0000
# gm_bpref                 28      -11.5129
# Rprec_mult_0.20          28      0.0000
# Rprec_mult_0.40          28      0.0000
# Rprec_mult_0.60          28      0.0000
# Rprec_mult_0.80          28      0.0000
# Rprec_mult_1.00          28      0.0000
# Rprec_mult_1.20          28      0.0000
# Rprec_mult_1.40          28      0.0000
# Rprec_mult_1.60          28      0.0000
# Rprec_mult_1.80          28      0.0000
# Rprec_mult_2.00          28      0.0000
# utility                  28      -22.0000
# 11pt_avg                 28      0.0000
# binG                     28      0.0000
# G                        28      0.0000
# ndcg                     28      0.0000
# ndcg_rel                 28      0.0000
# Rndcg                    28      0.0000
# ndcg_cut_5               28      0.0000
# ndcg_cut_10              28      0.0000
# ndcg_cut_15              28      0.0000
# ndcg_cut_20              28      0.0000
# ndcg_cut_30              28      0.0000
# ndcg_cut_100             28      0.0000
# ndcg_cut_200             28      0.0000
# ndcg_cut_500             28      0.0000
# ndcg_cut_1000            28      0.0000
# map_cut_5                28      0.0000
# map_cut_10               28      0.0000
# map_cut_15               28      0.0000
# map_cut_20               28      0.0000
# map_cut_30               28      0.0000
# map_cut_100              28      0.0000
# map_cut_200              28      0.0000
# map_cut_500              28      0.0000
# map_cut_1000             28      0.0000
# relative_P_5             28      0.0000
# relative_P_10            28      0.0000
# relative_P_15            28      0.0000
# relative_P_20            28      0.0000
# relative_P_30            28      0.0000
# relative_P_100           28      0.0000
# relative_P_200           28      0.0000
# relative_P_500           28      0.0000
# relative_P_1000          28      0.0000
# success_1                28      0.0000
# success_5                28      0.0000
# success_10               28      0.0000
# set_P                    28      0.0000
# set_relative_P           28      0.0000
# set_recall               28      0.0000
# set_map                  28      0.0000
# set_F                    28      0.0000
# num_nonrel_judged_ret    28      21.0000
# num_q                    all     14.0000
# num_ret                  all     151.0000
# num_rel                  all     33.0000
# num_rel_ret              all     7.0000
# map                      all     0.1971
# gm_map                   all     0.0015
# Rprec                    all     0.1667
# bpref                    all     0.1508
# recip_rank               all     0.2196
# iprec_at_recall_0.00     all     0.2196
# iprec_at_recall_0.10     all     0.2196
# iprec_at_recall_0.20     all     0.2196
# iprec_at_recall_0.30     all     0.2107
# iprec_at_recall_0.40     all     0.1869
# iprec_at_recall_0.50     all     0.1869
# iprec_at_recall_0.60     all     0.1869
# iprec_at_recall_0.70     all     0.1869
# iprec_at_recall_0.80     all     0.1869
# iprec_at_recall_0.90     all     0.1869
# iprec_at_recall_1.00     all     0.1869
# P_5                      all     0.0714
# P_10                     all     0.0500
# P_15                     all     0.0333
# P_20                     all     0.0250
# P_30                     all     0.0167
# P_100                    all     0.0050
# P_200                    all     0.0025
# P_500                    all     0.0010
# P_1000                   all     0.0005
# relstring                all     0.0000
# recall_5                 all     0.3095
# recall_10                all     0.3988
# recall_15                all     0.3988
# recall_20                all     0.3988
# recall_30                all     0.3988
# recall_100               all     0.3988
# recall_200               all     0.3988
# recall_500               all     0.3988
# recall_1000              all     0.3988
# infAP                    all     0.1971
# gm_bpref                 all     0.0001
# Rprec_mult_0.20          all     0.1429
# Rprec_mult_0.40          all     0.1429
# Rprec_mult_0.60          all     0.1429
# Rprec_mult_0.80          all     0.1667
# Rprec_mult_1.00          all     0.1667
# Rprec_mult_1.20          all     0.0893
# Rprec_mult_1.40          all     0.0857
# Rprec_mult_1.60          all     0.0857
# Rprec_mult_1.80          all     0.0923
# Rprec_mult_2.00          all     0.0923
# utility                  all     -9.7857
# 11pt_avg                 all     0.1980
# binG                     all     0.2442
# G                        all     0.2442
# ndcg                     all     0.2523
# ndcg_rel                 all     0.2523
# Rndcg                    all     0.2059
# ndcg_cut_5               all     0.2180
# ndcg_cut_10              all     0.2523
# ndcg_cut_15              all     0.2523
# ndcg_cut_20              all     0.2523
# ndcg_cut_30              all     0.2523
# ndcg_cut_100             all     0.2523
# ndcg_cut_200             all     0.2523
# ndcg_cut_500             all     0.2523
# ndcg_cut_1000            all     0.2523
# map_cut_5                all     0.1829
# map_cut_10               all     0.1971
# map_cut_15               all     0.1971
# map_cut_20               all     0.1971
# map_cut_30               all     0.1971
# map_cut_100              all     0.1971
# map_cut_200              all     0.1971
# map_cut_500              all     0.1971
# map_cut_1000             all     0.1971
# relative_P_5             all     0.3095
# relative_P_10            all     0.3988
# relative_P_15            all     0.3988
# relative_P_20            all     0.3988
# relative_P_30            all     0.3988
# relative_P_100           all     0.3988
# relative_P_200           all     0.3988
# relative_P_500           all     0.3988
# relative_P_1000          all     0.3988
# success_1                all     0.1429
# success_5                all     0.3571
# success_10               all     0.5000
# set_P                    all     0.0421
# set_relative_P           all     0.3988
# set_recall               all     0.3988
# set_map                  all     0.0357
# set_F                    all     0.0740
# num_nonrel_judged_ret    all     126.0000

# %%
q2.print_rel_name('16')
# Out:
# ---------------------------Topic_id and Topic_phrase----------------------------------
# 16 Emergency and disaster preparedness assistance
# ---------------------------Return documents----------------------------------
# 16 Q0 G00-34-3591274 0 34.092076 test
# 16 Q0 G00-05-0719078 1 32.195486 test
# 16 Q0 G00-92-2053892 2 27.131764 test
# 16 Q0 G00-70-2681284 3 26.574622 test
# 16 Q0 G00-33-2857182 4 21.813916 test
# 16 Q0 G00-51-3264753 5 10.948533 test
# 16 Q0 G00-32-1907807 6 10.008862 test
# ---------------------------Relevant documents----------------------------------
# 16 0 G00-03-0589290 1
# 16 0 G00-21-0494028 1
# 16 0 G00-21-2114990 1
# 16 0 G00-32-0551737 1
# 16 0 G00-86-3719816 1
# 16 0 G00-92-2974327 1
# 16 0 G00-99-0140748 1

# %% [markdown]
# ### Q2 (b): Provide answer to Q2 (b) here [markdown cell]
# The metric I chose - iprec_at_recall_1.00 all - was 0.1869.

# %% [markdown]
# ### Q2 (c): Provide answer to Q2(c) here [markdown cell]
# Yes it did well on topics 18 and 24 where the iprec_at_recall_1.00 was 1 for both of them. It did very badly for most of them, for example it got 0 on topics 1,2,4,6,7,9,16 and 26, and it got around 0.2 for all other topics.

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Q3 (a): Provide answer to Q3 (a) here [markdown cell]
# The query I investigated was query 16 "Emergency and disaster preparedness assistance", and the the false positive test case I investigated was G00-92-2053892 while the false negative test case I investigated was G00-21-0494028. I found that in the false negative case the word "emergency" did show up 3 times but the first letter was all capaitlized and one time it showed up as plural "Emergengies", the word "and" did not show up as many times as in the false positive document as in the false negative document but this word does not matter so it should be removed. The word "disaster" actually showed up many times in the false neagtive case but it showed up as plural sometimes too and also with first letter capitalized. For the word "preparedness", it showed up as "prepared" instead of the full noun in the negative case.
#
# **For proposed solution and resonaing:**
# I think the changes of adding a lower-case filter, a stop words filter, a strip filter, and a stemmer will all improve Whoosh's performance on this test collection. This is because sometimes the first letters of these words show up as either uppercase or lowercase; therefore, it is important to make them all lower case. The word like "and" " can show up a lot of times in a document and not mean anything, and a stop filter can solve this issue. The strip filter can filter out any potential odd characters. The stemmers will return just the stem of the words which then can get rid of things like plurals and past tense etc which shows up in words like "diasters" and "preparedness".

# %% [markdown]
# ### Q3 (b): Write your code below

# %% [markdown]
# **1. The auto-grader will extract and use the following variables, DON'T change the their names:**
#
#       self.topic_file
#       self.qrels_file
#       self.document_dir
#       self.file_list
#       self.index_sys
#       self.query_parser
#       self.searcher
#
#
#
# **2. DON'T change the names of the already defined funtions**
# **3. DON'T change the py_trec_eval function**
# **4. DON'T change the class names including CustomFilter, IRSystem, IRQ2, IRQ3, IRQ4**
# **5. DON'T change the CustomFilter class and DON'T create any new custom filter class that is used to define Whoosh schema**

# %%
myAnalyzer1 = RegexTokenizer() | LowercaseFilter() |  StopFilter() | StripFilter() | CustomFilter(LancasterStemmer().stem)

# %%
class IRQ3(IRSystem):
    def create_index(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Please update self.index_sys which should have type whoosh.index.FileIndex
        """
        # DON't change the name of 'index_sys'
        self.schema = Schema(file_path = ID(stored=True),
                             file_content = TEXT(analyzer = myAnalyzer1))
        self.index_sys = index.create_in(tempfile.mkdtemp(), self.schema)

    def add_files(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Add buffer to self.index_sys
        """
        # open writer
        writer = writing.BufferedWriter(self.index_sys, period=None, limit=1000)

        try:
            # write each file to index
            for docNum, filePath in enumerate(self.file_list):
                with open(filePath, "r", encoding="utf-8") as f:
                    fileContent = f.read()
                    writer.add_document(file_path = filePath,
                                        file_content = fileContent)

                    # print status every 1000 documents
                    if (docNum+1) % 1000 == 0:
                        print("already indexed:", docNum+1)
            print("done indexing.")

        finally:
            # close the index
            writer.close()

    def create_parser_searcher(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Please update self.query_parser and self.searcher which should have type whoosh.qparser.default.QueryParser and whoosh.searching.Searcher respectively 
        """
         # DON't change the names of 'query_parser' and 'searcher'
        self.query_parser = QueryParser("file_content", schema=self.schema)
        self.searcher = self.index_sys.searcher()

    def perform_search(self, topic_phrase):
        """
        INPUT:
            topic_phrase: string
        OUTPUT:
            topic_results: whoosh.searching.Results
        
        NOTE: Utilize self.query_parser and self.searcher to calculate the result for topic_phrase
        """
        query = self.query_parser.parse(topic_phrase)
        topic_results = self.searcher.search(query, limit=None)
        return topic_results

# %%
q3 = IRQ3("government")
# Out:
# already indexed: 1000
# already indexed: 2000
# already indexed: 3000
# already indexed: 4000
# done indexing.

# %%
q3.py_trec_eval()
# Out:
# num_q                    1       1.0000
# num_ret                  1       3.0000
# num_rel                  1       5.0000
# num_rel_ret              1       0.0000
# map                      1       0.0000
# gm_map                   1       -11.5129
# Rprec                    1       0.0000
# bpref                    1       0.0000
# recip_rank               1       0.0000
# iprec_at_recall_0.00     1       0.0000
# iprec_at_recall_0.10     1       0.0000
# iprec_at_recall_0.20     1       0.0000
# iprec_at_recall_0.30     1       0.0000
# iprec_at_recall_0.40     1       0.0000
# iprec_at_recall_0.50     1       0.0000
# iprec_at_recall_0.60     1       0.0000
# iprec_at_recall_0.70     1       0.0000
# iprec_at_recall_0.80     1       0.0000
# iprec_at_recall_0.90     1       0.0000
# iprec_at_recall_1.00     1       0.0000
# P_5                      1       0.0000
# P_10                     1       0.0000
# P_15                     1       0.0000
# P_20                     1       0.0000
# P_30                     1       0.0000
# P_100                    1       0.0000
# P_200                    1       0.0000
# P_500                    1       0.0000
# P_1000                   1       0.0000
# relstring                1       0.0000
# recall_5                 1       0.0000
# recall_10                1       0.0000
# recall_15                1       0.0000
# recall_20                1       0.0000
# recall_30                1       0.0000
# recall_100               1       0.0000
# recall_200               1       0.0000
# recall_500               1       0.0000
# recall_1000              1       0.0000
# infAP                    1       0.0000
# gm_bpref                 1       -11.5129
# Rprec_mult_0.20          1       0.0000
# Rprec_mult_0.40          1       0.0000
# Rprec_mult_0.60          1       0.0000
# Rprec_mult_0.80          1       0.0000
# Rprec_mult_1.60          2       0.2500
# Rprec_mult_1.80          2       0.2500
# Rprec_mult_2.00          2       0.2500
# utility                  2       -11.0000
# 11pt_avg                 2       0.5455
# binG                     2       0.5000
# G                        2       0.5000
# ndcg                     2       0.6131
# ndcg_rel                 2       0.8066
# Rndcg                    2       0.6131
# ndcg_cut_5               2       0.6131
# ndcg_cut_10              2       0.6131
# ndcg_cut_15              2       0.6131
# ndcg_cut_20              2       0.6131
# ndcg_cut_30              2       0.6131
# ndcg_cut_100             2       0.6131
# ndcg_cut_200             2       0.6131
# ndcg_cut_500             2       0.6131
# ndcg_cut_1000            2       0.6131
# map_cut_5                2       0.5000
# map_cut_10               2       0.5000
# map_cut_15               2       0.5000
# map_cut_20               2       0.5000
# map_cut_30               2       0.5000
# map_cut_100              2       0.5000
# map_cut_200              2       0.5000
# map_cut_500              2       0.5000
# map_cut_1000             2       0.5000
# relative_P_5             2       0.5000
# relative_P_10            2       0.5000
# relative_P_15            2       0.5000
# relative_P_20            2       0.5000
# relative_P_30            2       0.5000
# relative_P_100           2       0.5000
# relative_P_200           2       0.5000
# relative_P_500           2       0.5000
# relative_P_1000          2       0.5000
# success_1                2       1.0000
# success_5                2       1.0000
# success_10               2       1.0000
# set_P                    2       0.0769
# set_relative_P           2       0.5000
# set_recall               2       0.5000
# set_map                  2       0.0385
# set_F                    2       0.1333
# num_nonrel_judged_ret    2       9.0000
# num_q                    4       1.0000
# num_ret                  4       40.0000
# num_rel                  4       4.0000
# num_rel_ret              4       3.0000
# map                      4       0.5375
# gm_map                   4       -0.6208
# Rprec                    4       0.5000
# bpref                    4       0.5000
# recip_rank               4       1.0000
# iprec_at_recall_0.00     4       1.0000
# iprec_at_recall_0.10     4       1.0000
# iprec_at_recall_0.20     4       1.0000
# iprec_at_recall_0.30     4       1.0000
# iprec_at_recall_0.40     4       1.0000
# iprec_at_recall_0.50     4       1.0000
# iprec_at_recall_0.60     4       0.1500
# iprec_at_recall_0.70     4       0.1500
# iprec_at_recall_0.80     4       0.0000
# iprec_at_recall_0.90     4       0.0000
# iprec_at_recall_1.00     4       0.0000
# P_5                      4       0.4000
# P_10                     4       0.2000
# P_15                     4       0.1333
# P_20                     4       0.1500
# P_30                     4       0.1000
# P_100                    4       0.0300
# P_200                    4       0.0150
# P_500                    4       0.0060
# P_1000                   4       0.0030
# relstring                4       0.0000
# recall_5                 4       0.5000
# recall_10                4       0.5000
# recall_15                4       0.5000
# recall_20                4       0.7500
# recall_30                4       0.7500
# recall_100               4       0.7500
# recall_200               4       0.7500
# recall_500               4       0.7500
# recall_1000              4       0.7500
# infAP                    4       0.5375
# gm_bpref                 4       -0.6931
# Rprec_mult_0.20          4       1.0000
# Rprec_mult_0.40          4       1.0000
# Rprec_mult_0.60          4       0.6667
# Rprec_mult_0.80          4       0.5000
# Rprec_mult_1.00          4       0.5000
# Rprec_mult_1.20          4       0.4000
# Rprec_mult_1.40          4       0.3333
# Rprec_mult_1.60          4       0.2857
# Rprec_mult_1.80          4       0.2500
# ndcg                     7       0.0000
# ndcg_rel                 7       0.0000
# Rndcg                    7       0.0000
# ndcg_cut_5               7       0.0000
# ndcg_cut_10              7       0.0000
# ndcg_cut_15              7       0.0000
# ndcg_cut_20              7       0.0000
# ndcg_cut_30              7       0.0000
# ndcg_cut_100             7       0.0000
# ndcg_cut_200             7       0.0000
# ndcg_cut_500             7       0.0000
# ndcg_cut_1000            7       0.0000
# map_cut_5                7       0.0000
# map_cut_10               7       0.0000
# map_cut_15               7       0.0000
# map_cut_20               7       0.0000
# map_cut_30               7       0.0000
# map_cut_100              7       0.0000
# map_cut_200              7       0.0000
# map_cut_500              7       0.0000
# map_cut_1000             7       0.0000
# relative_P_5             7       0.0000
# relative_P_10            7       0.0000
# relative_P_15            7       0.0000
# relative_P_20            7       0.0000
# relative_P_30            7       0.0000
# relative_P_100           7       0.0000
# relative_P_200           7       0.0000
# relative_P_500           7       0.0000
# relative_P_1000          7       0.0000
# success_1                7       0.0000
# success_5                7       0.0000
# success_10               7       0.0000
# set_P                    7       0.0000
# set_relative_P           7       0.0000
# set_recall               7       0.0000
# set_map                  7       0.0000
# set_F                    7       0.0000
# num_nonrel_judged_ret    7       11.0000
# num_q                    9       1.0000
# num_ret                  9       27.0000
# num_rel                  9       1.0000
# num_rel_ret              9       1.0000
# map                      9       0.0556
# gm_map                   9       -2.8904
# Rprec                    9       0.0000
# bpref                    9       0.0000
# recip_rank               9       0.0556
# iprec_at_recall_0.00     9       0.0556
# iprec_at_recall_0.10     9       0.0556
# iprec_at_recall_0.20     9       0.0556
# iprec_at_recall_0.30     9       0.0556
# iprec_at_recall_0.40     9       0.0556
# iprec_at_recall_0.50     9       0.0556
# iprec_at_recall_0.60     9       0.0556
# iprec_at_recall_0.70     9       0.0556
# iprec_at_recall_0.80     9       0.0556
# iprec_at_recall_0.90     9       0.0556
# iprec_at_recall_1.00     9       0.0556
# P_5                      9       0.0000
# P_10                     9       0.0000
# P_15                     9       0.0000
# P_20                     9       0.0500
# P_30                     9       0.0333
# P_100                    9       0.0100
# P_200                    9       0.0050
# P_500                    9       0.0020
# P_1000                   9       0.0010
# relstring                9       0.0000
# recall_5                 9       0.0000
# recall_10                9       0.0000
# recall_15                9       0.0000
# recall_20                9       1.0000
# recall_30                9       1.0000
# recall_100               9       1.0000
# recall_200               9       1.0000
# recall_500               9       1.0000
# recall_1000              9       1.0000
# infAP                    9       0.0556
# gm_bpref                 9       -11.5129
# Rprec_mult_0.20          9       0.0000
# Rprec_mult_0.40          9       0.0000
# Rprec_mult_0.60          9       0.0000
# Rprec_mult_0.80          9       0.0000
# Rprec_mult_1.00          9       0.0000
# Rprec_mult_1.20          9       0.0000
# Rprec_mult_1.40          9       0.0000
# Rprec_mult_1.60          9       0.0000
# Rprec_mult_1.80          9       0.0000
# Rprec_mult_2.00          9       0.0000
# utility                  9       -25.0000
# 11pt_avg                 9       0.0556
# binG                     9       0.2354
# G                        9       0.2354
# ndcg                     9       0.2354
# ndcg_rel                 9       0.2354
# Rndcg                    9       0.1177
# ndcg_cut_5               9       0.0000
# ndcg_cut_10              9       0.0000
# ndcg_cut_15              9       0.0000
# ndcg_cut_20              9       0.2354
# ndcg_cut_30              9       0.2354
# ndcg_cut_100             9       0.2354
# ndcg_cut_200             9       0.2354
# ndcg_cut_500             9       0.2354
# ndcg_cut_1000            9       0.2354
# map_cut_5                9       0.0000
# map_cut_10               9       0.0000
# map_cut_15               9       0.0000
# map_cut_20               9       0.0556
# map_cut_30               9       0.0556
# map_cut_100              9       0.0556
# map_cut_200              9       0.0556
# map_cut_500              9       0.0556
# map_cut_1000             9       0.0556
# relative_P_5             9       0.0000
# relative_P_10            9       0.0000
# relative_P_15            9       0.0000
# relative_P_20            9       1.0000
# relative_P_30            9       1.0000
# relative_P_100           9       1.0000
# relative_P_200           9       1.0000
# relative_P_500           9       1.0000
# relative_P_1000          9       1.0000
# success_1                9       0.0000
# success_5                9       0.0000
# success_10               9       0.0000
# set_P                    9       0.0370
# set_relative_P           9       1.0000
# set_recall               9       1.0000
# set_map                  9       0.0370
# set_F                    9       0.0714
# num_nonrel_judged_ret    9       23.0000
# num_q                    10      1.0000
# num_ret                  10      54.0000
# num_rel                  10      1.0000
# num_rel_ret              10      1.0000
# map                      10      0.2500
# gm_map                   10      -1.3863
# Rprec                    10      0.0000
# bpref                    10      0.0000
# recip_rank               10      0.2500
# iprec_at_recall_0.00     10      0.2500
# iprec_at_recall_0.10     10      0.2500
# iprec_at_recall_0.20     10      0.2500
# iprec_at_recall_0.30     10      0.2500
# iprec_at_recall_0.40     10      0.2500
# iprec_at_recall_0.50     10      0.2500
# iprec_at_recall_0.60     10      0.2500
# iprec_at_recall_0.70     10      0.2500
# iprec_at_recall_0.80     10      0.2500
# iprec_at_recall_0.90     10      0.2500
# iprec_at_recall_1.00     10      0.2500
# P_5                      10      0.2000
# P_10                     10      0.1000
# P_15                     10      0.0667
# P_20                     10      0.0500
# P_30                     10      0.0333
# P_100                    10      0.0100
# P_200                    10      0.0050
# P_500                    10      0.0020
# P_1000                   10      0.0010
# relstring                10      0.0000
# recall_5                 10      1.0000
# recall_10                10      1.0000
# recall_15                10      1.0000
# recall_20                10      1.0000
# recall_30                10      1.0000
# recall_100               10      1.0000
# recall_200               10      1.0000
# recall_500               10      1.0000
# recall_1000              10      1.0000
# infAP                    10      0.2500
# gm_bpref                 10      -11.5129
# Rprec_mult_0.20          10      0.0000
# Rprec_mult_0.40          10      0.0000
# Rprec_mult_0.60          10      0.0000
# Rprec_mult_0.80          10      0.0000
# Rprec_mult_1.00          10      0.0000
# Rprec_mult_1.20          10      0.0000
# Rprec_mult_1.40          10      0.0000
# Rprec_mult_1.60          10      0.0000
# Rprec_mult_1.80          10      0.0000
# Rprec_mult_2.00          10      0.0000
# utility                  10      -52.0000
# 11pt_avg                 10      0.2500
# binG                     10      0.4307
# G                        10      0.4307
# ndcg                     10      0.4307
# ndcg_rel                 10      0.4307
# Rndcg                    10      0.2153
# ndcg_cut_5               10      0.4307
# ndcg_cut_10              10      0.4307
# ndcg_cut_15              10      0.4307
# ndcg_cut_20              10      0.4307
# ndcg_cut_30              10      0.4307
# ndcg_cut_100             10      0.4307
# ndcg_cut_200             10      0.4307
# ndcg_cut_500             10      0.4307
# ndcg_cut_1000            10      0.4307
# map_cut_5                10      0.2500
# map_cut_10               10      0.2500
# map_cut_15               10      0.2500
# map_cut_20               10      0.2500
# map_cut_30               10      0.2500
# map_cut_100              10      0.2500
# map_cut_200              10      0.2500
# map_cut_500              10      0.2500
# map_cut_1000             10      0.2500
# relative_P_5             10      1.0000
# relative_P_10            10      1.0000
# relative_P_15            10      1.0000
# relative_P_20            10      1.0000
# relative_P_30            10      1.0000
# relative_P_100           10      1.0000
# relative_P_200           10      1.0000
# relative_P_500           10      1.0000
# relative_P_1000          10      1.0000
# success_1                10      0.0000
# success_5                10      1.0000
# success_10               10      1.0000
# set_P                    10      0.0185
# set_relative_P           10      1.0000
# set_recall               10      1.0000
# set_map                  10      0.0185
# set_F                    10      0.0364
# num_nonrel_judged_ret    10      16.0000
# num_q                    14      1.0000
# num_ret                  14      26.0000
# num_rel                  14      1.0000
# num_rel_ret              14      1.0000
# map                      14      1.0000
# gm_map                   14      0.0000
# Rprec                    14      1.0000
# bpref                    14      1.0000
# recip_rank               14      1.0000
# iprec_at_recall_0.00     14      1.0000
# iprec_at_recall_0.10     14      1.0000
# iprec_at_recall_0.20     14      1.0000
# iprec_at_recall_0.30     14      1.0000
# iprec_at_recall_0.40     14      1.0000
# iprec_at_recall_0.50     14      1.0000
# iprec_at_recall_0.60     14      1.0000
# iprec_at_recall_0.70     14      1.0000
# iprec_at_recall_0.80     14      1.0000
# iprec_at_recall_0.90     14      1.0000
# iprec_at_recall_1.00     14      1.0000
# P_5                      14      0.2000
# P_10                     14      0.1000
# P_15                     14      0.0667
# P_20                     14      0.0500
# P_30                     14      0.0333
# P_100                    14      0.0100
# P_200                    14      0.0050
# P_500                    14      0.0020
# P_1000                   14      0.0010
# relstring                14      0.0000
# recall_5                 14      1.0000
# recall_10                14      1.0000
# recall_15                14      1.0000
# recall_20                14      1.0000
# recall_30                14      1.0000
# recall_100               14      1.0000
# recall_200               14      1.0000
# recall_500               14      1.0000
# recall_1000              14      1.0000
# infAP                    14      1.0000
# gm_bpref                 14      0.0000
# Rprec_mult_0.20          14      1.0000
# Rprec_mult_0.40          14      1.0000
# Rprec_mult_0.60          14      1.0000
# Rprec_mult_0.80          14      1.0000
# Rprec_mult_1.00          14      1.0000
# Rprec_mult_1.20          14      0.5000
# Rprec_mult_1.40          14      0.5000
# Rprec_mult_1.60          14      0.5000
# Rprec_mult_1.80          14      0.5000
# Rprec_mult_2.00          14      0.5000
# utility                  14      -24.0000
# 11pt_avg                 14      1.0000
# binG                     14      1.0000
# G                        14      1.0000
# ndcg                     14      1.0000
# ndcg_rel                 14      1.0000
# Rndcg                    14      1.0000
# ndcg_cut_5               14      1.0000
# ndcg_cut_10              14      1.0000
# ndcg_cut_15              14      1.0000
# ndcg_cut_20              14      1.0000
# ndcg_cut_30              14      1.0000
# map_cut_500              22      0.0357
# map_cut_1000             22      0.0357
# relative_P_5             22      0.0000
# relative_P_10            22      0.0000
# relative_P_15            22      0.0000
# relative_P_20            22      0.0000
# relative_P_30            22      1.0000
# relative_P_100           22      1.0000
# relative_P_200           22      1.0000
# relative_P_500           22      1.0000
# relative_P_1000          22      1.0000
# success_1                22      0.0000
# success_5                22      0.0000
# success_10               22      0.0000
# set_P                    22      0.0093
# set_relative_P           22      1.0000
# set_recall               22      1.0000
# set_map                  22      0.0093
# set_F                    22      0.0185
# num_nonrel_judged_ret    22      72.0000
# num_q                    24      1.0000
# num_ret                  24      24.0000
# num_rel                  24      1.0000
# num_rel_ret              24      1.0000
# map                      24      1.0000
# gm_map                   24      0.0000
# Rprec                    24      1.0000
# bpref                    24      1.0000
# recip_rank               24      1.0000
# iprec_at_recall_0.00     24      1.0000
# iprec_at_recall_0.10     24      1.0000
# iprec_at_recall_0.20     24      1.0000
# iprec_at_recall_0.30     24      1.0000
# iprec_at_recall_0.40     24      1.0000
# iprec_at_recall_0.50     24      1.0000
# iprec_at_recall_0.60     24      1.0000
# iprec_at_recall_0.70     24      1.0000
# iprec_at_recall_0.80     24      1.0000
# iprec_at_recall_0.90     24      1.0000
# iprec_at_recall_1.00     24      1.0000
# P_5                      24      0.2000
# P_10                     24      0.1000
# P_15                     24      0.0667
# P_20                     24      0.0500
# P_30                     24      0.0333
# P_100                    24      0.0100
# P_200                    24      0.0050
# P_500                    24      0.0020
# P_1000                   24      0.0010
# relstring                24      0.0000
# recall_5                 24      1.0000
# recall_10                24      1.0000
# recall_15                24      1.0000
# recall_20                24      1.0000
# recall_30                24      1.0000
# recall_100               24      1.0000
# recall_200               24      1.0000
# recall_500               24      1.0000
# recall_1000              24      1.0000
# infAP                    24      1.0000
# gm_bpref                 24      0.0000
# Rprec_mult_0.20          24      1.0000
# Rprec_mult_0.40          24      1.0000
# Rprec_mult_0.60          24      1.0000
# Rprec_mult_0.80          24      1.0000
# Rprec_mult_1.00          24      1.0000
# Rprec_mult_1.20          24      0.5000
# Rprec_mult_1.40          24      0.5000
# Rprec_mult_1.60          24      0.5000
# Rprec_mult_1.80          24      0.5000
# Rprec_mult_2.00          24      0.5000
# utility                  24      -22.0000
# 11pt_avg                 24      1.0000
# binG                     24      1.0000
# G                        24      1.0000
# ndcg                     24      1.0000
# ndcg_rel                 24      1.0000
# Rndcg                    24      1.0000
# ndcg_cut_5               24      1.0000
# ndcg_cut_10              24      1.0000
# ndcg_cut_15              24      1.0000
# ndcg_cut_20              24      1.0000
# ndcg_cut_30              24      1.0000
# ndcg_cut_100             24      1.0000
# ndcg_cut_200             24      1.0000
# ndcg_cut_500             24      1.0000
# ndcg_cut_1000            24      1.0000
# map_cut_5                24      1.0000
# map_cut_10               24      1.0000
# map_cut_15               24      1.0000
# map_cut_20               24      1.0000
# map_cut_30               24      1.0000
# map_cut_100              24      1.0000
# map_cut_200              24      1.0000
# map_cut_500              24      1.0000
# map_cut_1000             24      1.0000
# relative_P_20            26      0.3333
# relative_P_30            26      0.3333
# relative_P_100           26      0.6667
# relative_P_200           26      0.6667
# relative_P_500           26      0.6667
# relative_P_1000          26      0.6667
# success_1                26      0.0000
# success_5                26      0.0000
# success_10               26      1.0000
# set_P                    26      0.0385
# set_relative_P           26      0.6667
# set_recall               26      0.6667
# set_map                  26      0.0256
# set_F                    26      0.0727
# num_nonrel_judged_ret    26      36.0000
# num_q                    28      1.0000
# num_ret                  28      64.0000
# num_rel                  28      2.0000
# num_rel_ret              28      2.0000
# map                      28      0.2262
# gm_map                   28      -1.4864
# Rprec                    28      0.0000
# bpref                    28      0.0000
# recip_rank               28      0.1667
# iprec_at_recall_0.00     28      0.2857
# iprec_at_recall_0.10     28      0.2857
# iprec_at_recall_0.20     28      0.2857
# iprec_at_recall_0.30     28      0.2857
# iprec_at_recall_0.40     28      0.2857
# iprec_at_recall_0.50     28      0.2857
# iprec_at_recall_0.60     28      0.2857
# iprec_at_recall_0.70     28      0.2857
# iprec_at_recall_0.80     28      0.2857
# iprec_at_recall_0.90     28      0.2857
# iprec_at_recall_1.00     28      0.2857
# P_5                      28      0.0000
# P_10                     28      0.2000
# P_15                     28      0.1333
# P_20                     28      0.1000
# P_30                     28      0.0667
# P_100                    28      0.0200
# P_200                    28      0.0100
# P_500                    28      0.0040
# P_1000                   28      0.0020
# relstring                28      0.0000
# recall_5                 28      0.0000
# recall_10                28      1.0000
# recall_15                28      1.0000
# recall_20                28      1.0000
# recall_30                28      1.0000
# recall_100               28      1.0000
# recall_200               28      1.0000
# recall_500               28      1.0000
# recall_1000              28      1.0000
# infAP                    28      0.2262
# gm_bpref                 28      -11.5129
# Rprec_mult_0.20          28      0.0000
# Rprec_mult_0.40          28      0.0000
# Rprec_mult_0.60          28      0.0000
# Rprec_mult_0.80          28      0.0000
# Rprec_mult_1.00          28      0.0000
# Rprec_mult_1.20          28      0.0000
# Rprec_mult_1.40          28      0.0000
# Rprec_mult_1.60          28      0.0000
# Rprec_mult_1.80          28      0.0000
# Rprec_mult_2.00          28      0.0000
# utility                  28      -60.0000
# 11pt_avg                 28      0.2857
# binG                     28      0.3562
# G                        28      0.3562
# ndcg                     28      0.4228
# ndcg_rel                 28      0.3206
# Rndcg                    28      0.2114
# ndcg_cut_5               28      0.0000
# ndcg_cut_10              28      0.4228
# ndcg_cut_15              28      0.4228
# ndcg_cut_20              28      0.4228
# ndcg_cut_30              28      0.4228
# ndcg_cut_100             28      0.4228
# ndcg_cut_200             28      0.4228
# ndcg_cut_500             28      0.4228
# ndcg_cut_1000            28      0.4228
# map_cut_5                28      0.0000
# map_cut_10               28      0.2262
# map_cut_15               28      0.2262
# map_cut_20               28      0.2262
# map_cut_30               28      0.2262
# map_cut_100              28      0.2262
# map_cut_200              28      0.2262
# map_cut_500              28      0.2262
# map_cut_1000             28      0.2262
# relative_P_5             28      0.0000
# relative_P_10            28      1.0000
# relative_P_15            28      1.0000
# relative_P_20            28      1.0000
# relative_P_30            28      1.0000
# relative_P_100           28      1.0000
# relative_P_200           28      1.0000
# relative_P_500           28      1.0000
# relative_P_1000          28      1.0000
# success_1                28      0.0000
# success_5                28      0.0000
# success_10               28      1.0000
# set_P                    28      0.0312
# set_relative_P           28      1.0000
# set_recall               28      1.0000
# set_map                  28      0.0312
# set_F                    28      0.0606
# num_nonrel_judged_ret    28      28.0000
# num_q                    all     15.0000
# num_ret                  all     509.0000
# num_rel                  all     35.0000
# num_rel_ret              all     15.0000
# map                      all     0.3455
# gm_map                   all     0.0187
# Rprec                    all     0.3000
# bpref                    all     0.3000
# recip_rank               all     0.4450
# iprec_at_recall_0.00     all     0.4529
# iprec_at_recall_0.10     all     0.4529
# iprec_at_recall_0.20     all     0.4529
# iprec_at_recall_0.30     all     0.4529
# iprec_at_recall_0.40     all     0.4461
# iprec_at_recall_0.50     all     0.4461
# iprec_at_recall_0.60     all     0.2561
# iprec_at_recall_0.70     all     0.2561
# iprec_at_recall_0.80     all     0.2418
# iprec_at_recall_0.90     all     0.2418
# iprec_at_recall_1.00     all     0.2418
# P_5                      all     0.1067
# P_10                     all     0.0733
# P_15                     all     0.0489
# P_20                     all     0.0433
# P_30                     all     0.0311
# P_100                    all     0.0100
# P_200                    all     0.0050
# P_500                    all     0.0020
# P_1000                   all     0.0010
# relstring                all     0.0000
# recall_5                 all     0.3667
# recall_10                all     0.4556
# recall_15                all     0.4556
# recall_20                all     0.5389
# recall_30                all     0.6056
# recall_100               all     0.6278
# recall_200               all     0.6278
# recall_500               all     0.6278
# recall_1000              all     0.6278
# infAP                    all     0.3455
# gm_bpref                 all     0.0009
# Rprec_mult_0.20          all     0.4000
# Rprec_mult_0.40          all     0.4000
# Rprec_mult_0.60          all     0.3111
# Rprec_mult_0.80          all     0.3000
# Rprec_mult_1.00          all     0.3000
# Rprec_mult_1.20          all     0.1711
# Rprec_mult_1.40          all     0.1667
# Rprec_mult_1.60          all     0.1524
# Rprec_mult_1.80          all     0.1611
# Rprec_mult_2.00          all     0.1611
# utility                  all     -31.9333
# 11pt_avg                 all     0.3583
# binG                     all     0.3982
# G                        all     0.3982
# ndcg                     all     0.4338
# ndcg_rel                 all     0.4599
# Rndcg                    all     0.3790
# ndcg_cut_5               all     0.3529
# ndcg_cut_10              all     0.3922
# ndcg_cut_15              all     0.3922
# ndcg_cut_20              all     0.4139
# ndcg_cut_30              all     0.4276
# ndcg_cut_100             all     0.4338
# ndcg_cut_200             all     0.4338
# ndcg_cut_500             all     0.4338
# ndcg_cut_1000            all     0.4338
# map_cut_5                all     0.3167
# map_cut_10               all     0.3354
# map_cut_15               all     0.3354
# map_cut_20               all     0.3417
# map_cut_30               all     0.3440
# map_cut_100              all     0.3455
# map_cut_200              all     0.3455
# map_cut_500              all     0.3455
# map_cut_1000             all     0.3455
# relative_P_5             all     0.3667
# relative_P_10            all     0.4556
# relative_P_15            all     0.4556
# relative_P_20            all     0.5389
# relative_P_30            all     0.6056
# relative_P_100           all     0.6278
# relative_P_200           all     0.6278
# relative_P_500           all     0.6278
# relative_P_1000          all     0.6278
# success_1                all     0.4000
# success_5                all     0.4667
# success_10               all     0.6000
# set_P                    all     0.0399
# set_relative_P           all     0.6278
# set_recall               all     0.6278
# set_map                  all     0.0285
# set_F                    all     0.0686
# num_nonrel_judged_ret    all     329.0000

# %%
q3.print_rel_name('16')
# Out:
# ---------------------------Topic_id and Topic_phrase----------------------------------
# 16 Emergency and disaster preparedness assistance
# ---------------------------Return documents----------------------------------
# 16 Q0 G00-68-3661801 0 24.587401 test
# 16 Q0 G00-34-3591274 1 24.315923 test
# 16 Q0 G00-70-2681284 2 23.245521 test
# 16 Q0 G00-03-2245885 3 23.203165 test
# 16 Q0 G00-05-0719078 4 23.178558 test
# 16 Q0 G00-88-2853984 5 23.084678 test
# 16 Q0 G00-45-0006211 6 23.084678 test
# 16 Q0 G00-84-2647789 7 22.750629 test
# 16 Q0 G00-20-3839216 8 21.989272 test
# 16 Q0 G00-92-2053892 9 21.895389 test
# 16 Q0 G00-93-0870338 10 21.537457 test
# 16 Q0 G00-14-0931254 11 20.573064 test
# 16 Q0 G00-46-3010333 12 20.466274 test
# 16 Q0 G00-33-2857182 13 18.790767 test
# 16 Q0 G00-75-3633903 14 18.190679 test
# 16 Q0 G00-56-2140972 15 17.853890 test
# 16 Q0 G00-49-2630728 16 17.747169 test
# 16 Q0 G00-23-1010771 17 17.250207 test
# 16 Q0 G00-30-1702552 18 14.587239 test
# 16 Q0 G00-15-3335359 19 14.492165 test
# 16 Q0 G00-51-3264753 20 13.403556 test
# 16 Q0 G00-40-1599376 21 12.606789 test
# 16 Q0 G00-23-3822276 22 11.848021 test
# 16 Q0 G00-79-0620805 23 11.630418 test
# 16 Q0 G00-32-1907807 24 11.471707 test
# 16 Q0 G00-21-1913322 25 10.207510 test
# 16 Q0 G00-82-3144058 26 10.021656 test
# 16 Q0 G00-68-4089689 27 9.492407 test
# 16 Q0 G00-56-3884873 28 9.122556 test
# 16 Q0 G00-23-3770912 29 7.036103 test
# 16 Q0 G00-46-0840102 30 6.527944 test
# 16 Q0 G00-33-2347653 31 5.677619 test
# 16 Q0 G00-24-3625720 32 4.774187 test
# ---------------------------Relevant documents----------------------------------
# 16 0 G00-03-0589290 1
# 16 0 G00-21-0494028 1
# 16 0 G00-21-2114990 1
# 16 0 G00-32-0551737 1
# 16 0 G00-86-3719816 1
# 16 0 G00-92-2974327 1
# 16 0 G00-99-0140748 1

# %% [markdown]
# ### Q3 (c): Provide answer to Q3 (c) here [markdown cell]
# The modifications I made are: adding a lower-case filter, a stop words filter, a strip filter, and a stemmer.
# Yes there were improvements over some queries in performance using the iprec_at_recall_1.00 score; for example, the performance of topics 9, 10, 14 and 28 all improved in terms of iprec_at_recall_1.00 score.The false negative case still exists from part a but the score for it is lower this time compared to in part a, and the document is lower ranked on the relevant documents list; however, the false positive case from part a did not get improved.

# %% [markdown]
# ### Q3 (d): Provide answer to Q3 (d) here [markdown cell]
# Yes it overall improved the average iprec_at_recall_1.00     all    to  0.2418 from the original 0.1869.

# %% [markdown]
# ### Q3 (e): Provide answer to Q3 (e) here [markdown cell]
# Yes. For example query 22 became 0.03 when it was 0.2 before, and query 14 became 1 when it was 0 before.

# %% [markdown]
# ### Q3 (f): Provide answer to Q3 (f) here [markdown cell]
# I think it means the idea is good overall as it did make an overall improvement on the iprec_at_recall_1.00 score. Also when I look at other scores like overall map, it also improved from 0.19 to 0.35. However as it made some queries performed worse, I believe there is still room for improvement on the searcher in order for it to do even better.

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Q4 (a): Provide answer to Q4 (a) here [markdown cell]
#
# I found that the first letter was all capaitlized in some words, but this should not make a difference verus an uncapitalized word in the search; distinguishing them would lead to a low performing model. Other common words like "and", "the" etc. which exists in the queries' topics can show up many times in a document, but these words are not importamt so they should be removed. Another cause of bad model performance is when there are many compound words that can show up with a "-" in between the subgroups; for example, "wireless" vs "wire-less" and this does not create a match anymore between the words. In order to avoid sparseness and allow words to show up in various forms like plural singular future and past tense etc, the compound words should be splitted and stripped down to their stem words. Otherwise this can cause a bad model result where relevant words are not picked up by the search.
#
# I also find that another source of bad model performance is caused by the searcher requring all the words in the topic query to be present inside the document. This is sometimes no the case because a relevant document does not need to contain all the words in the topic. A bad relevance scoring function can cause the relevance rank of the dcouments to be skewed as well.

# %% [markdown]
# ### Q4 (b): Write your code below

# %% [markdown]
# **1. The auto-grader will extract and use the following variables, DON'T change the their names:**
#
#       self.topic_file
#       self.qrels_file
#       self.document_dir
#       self.file_list
#       self.index_sys
#       self.query_parser
#       self.searcher
#
#
#
# **2. DON'T change the names of the already defined funtions**
# **3. DON'T change the py_trec_eval function**
# **4. DON'T change the class names including CustomFilter, IRSystem, IRQ2, IRQ3, IRQ4**
# **5. DON'T change the CustomFilter class and DON'T create any new custom filter class that is used to define Whoosh schema**

# %%
#tried but not the final proposed solution
myAnalyzer2 = RegexTokenizer() | LowercaseFilter() |  StopFilter() | StripFilter() | CompoundWordFilter(['bio', 'technology', 'cyber', 'crime', 'child', 'hood'], keep_compound=True) |CustomFilter(LancasterStemmer().stem)

# %%
#tried but not the final proposed solution
myAnalyzer3 = RegexTokenizer() | LowercaseFilter() |  StopFilter() | StripFilter() | CompoundWordFilter(wordnet, keep_compound=False) |CustomFilter(LancasterStemmer().stem)

# %%
# final proposed analyzer
myAnalyzer4 = RegexTokenizer() | LowercaseFilter() | IntraWordFilter() | StopFilter() | StripFilter() | CustomFilter(LancasterStemmer().stem)

# %%
#tried but not the final proposed solution
myAnalyzer5 = RegexTokenizer() | LowercaseFilter() | IntraWordFilter() | StopFilter() | StripFilter() | CustomFilter(WordNetLemmatizer().lemmatize)

# %%
#tried but not the final proposed solution
myAnalyzer6 = RegexTokenizer() | LowercaseFilter() | IntraWordFilter() | StopFilter() | StripFilter() | CustomFilter(WordNetLemmatizer().lemmatize, 'v')

# %%
#tried but not the final proposed solution
w_new1 = scoring.BM25F(B=0.6, K1=2)

# %%
#tried but not the final proposed solution
w_new2 = scoring.BM25F(B=0.6, K1=2.5)

# %%
#tried but not the final proposed solution
w_new3 = scoring.BM25F(B=0.6, K1=1.9)

# %%
# final proposed scoring function paramaters
w_new4 = scoring.BM25F(B=0.5, K1=1.9)

# %%
#tried but not the final proposed solution
w_new5 = scoring.BM25F(B=0.4, K1=1.9)

# %%
#tried but not the final proposed solution
w_new6 = scoring.BM25F(B=0.8, K1=1.9)

# %%
class IRQ4(IRSystem):
    def create_index(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Please update self.index_sys which should have type whoosh.index.FileIndex
        """
        # DON't change the name of 'index_sys'
        self.schema = Schema(file_path = ID(stored=True),
                             file_content = TEXT(analyzer = myAnalyzer4))
        self.index_sys = index.create_in(tempfile.mkdtemp(), self.schema)

    def add_files(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Add buffer to self.index_sys
        """
        # open writer
        writer = writing.BufferedWriter(self.index_sys, period=None, limit=1000)

        try:
            # write each file to index
            for docNum, filePath in enumerate(self.file_list):
                with open(filePath, "r", encoding="utf-8") as f:
                    fileContent = f.read()
                    writer.add_document(file_path = filePath,
                                        file_content = fileContent)

                    # print status every 1000 documents
                    if (docNum+1) % 1000 == 0:
                        print("already indexed:", docNum+1)
            print("done indexing.")

        finally:
            # close the index
            writer.close()

    def create_parser_searcher(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Please update self.query_parser and self.searcher which should have type whoosh.qparser.default.QueryParser and whoosh.searching.Searcher respectively 
        """
         # DON't change the names of 'query_parser' and 'searcher'
         # changed parser to "or group" instead of the default "and"
        self.query_parser = QueryParser("file_content", schema=self.schema, group=qparser.OrGroup)
        self.searcher = self.index_sys.searcher(weighting = w_new4)

    def perform_search(self, topic_phrase):
        """
        INPUT:
            topic_phrase: string
        OUTPUT:
            topic_results: whoosh.searching.Results
        
        NOTE: Utilize self.query_parser and self.searcher to calculate the result for topic_phrase
        """
        query = self.query_parser.parse(topic_phrase)
        topic_results = self.searcher.search(query, limit=None)
        return topic_results

# %%
q4 = IRQ4("government")
# Out:
# already indexed: 1000
# already indexed: 2000
# already indexed: 3000
# already indexed: 4000
# done indexing.

# %%
q4.py_trec_eval()
# Out:
# num_q                    1       1.0000
# num_ret                  1       481.0000
# num_rel                  1       5.0000
# num_rel_ret              1       5.0000
# map                      1       0.0624
# gm_map                   1       -2.7741
# Rprec                    1       0.0000
# bpref                    1       0.0000
# recip_rank               1       0.0526
# iprec_at_recall_0.00     1       0.1034
# iprec_at_recall_0.10     1       0.1034
# iprec_at_recall_0.20     1       0.1034
# iprec_at_recall_0.30     1       0.1034
# iprec_at_recall_0.40     1       0.1034
# iprec_at_recall_0.50     1       0.1034
# iprec_at_recall_0.60     1       0.1034
# iprec_at_recall_0.70     1       0.0455
# iprec_at_recall_0.80     1       0.0455
# iprec_at_recall_0.90     1       0.0391
# iprec_at_recall_1.00     1       0.0391
# P_5                      1       0.0000
# P_10                     1       0.0000
# P_15                     1       0.0000
# P_20                     1       0.0500
# P_30                     1       0.1000
# P_100                    1       0.0400
# P_200                    1       0.0250
# P_500                    1       0.0100
# P_1000                   1       0.0050
# relstring                1       0.0000
# recall_5                 1       0.0000
# recall_10                1       0.0000
# recall_15                1       0.0000
# recall_20                1       0.2000
# recall_30                1       0.6000
# recall_100               1       0.8000
# recall_200               1       1.0000
# recall_500               1       1.0000
# recall_1000              1       1.0000
# infAP                    1       0.0624
# gm_bpref                 1       -11.5129
# Rprec_mult_0.20          1       0.0000
# Rprec_mult_0.40          1       0.0000
# Rprec_mult_0.60          1       0.0000
# Rprec_mult_0.80          1       0.0000
# Rprec_mult_1.00          1       0.0000
# Rprec_mult_1.20          1       0.0000
# Rprec_mult_1.40          1       0.0000
# Rprec_mult_1.60          1       0.0000
# Rprec_mult_1.80          1       0.0000
# Rprec_mult_2.00          1       0.0000
# utility                  1       -471.0000
# 11pt_avg                 1       0.0812
# binG                     1       0.1893
# G                        1       0.1893
# ndcg                     1       0.3182
# ndcg_rel                 1       0.2064
# Rndcg                    1       0.1591
# ndcg_cut_5               1       0.0000
# ndcg_cut_10              1       0.0000
# ndcg_cut_15              1       0.0000
# ndcg_cut_20              1       0.0785
# ndcg_cut_30              1       0.2174
# ndcg_cut_100             1       0.2698
# ndcg_cut_200             1       0.3182
# ndcg_cut_500             1       0.3182
# ndcg_cut_1000            1       0.3182
# map_cut_5                1       0.0000
# map_cut_10               1       0.0000
# map_cut_15               1       0.0000
# map_cut_20               1       0.0105
# map_cut_30               1       0.0455
# map_cut_100              1       0.0546
# map_cut_200              1       0.0624
# map_cut_500              1       0.0624
# map_cut_1000             1       0.0624
# relative_P_5             1       0.0000
# relative_P_10            1       0.0000
# relative_P_15            1       0.0000
# relative_P_20            1       0.2000
# relative_P_30            1       0.6000
# relative_P_100           1       0.8000
# relative_P_200           1       1.0000
# relative_P_500           1       1.0000
# relative_P_1000          1       1.0000
# success_1                1       0.0000
# success_5                1       0.0000
# success_10               1       0.0000
# set_P                    1       0.0104
# set_relative_P           1       1.0000
# set_recall               1       1.0000
# set_map                  1       0.0104
# set_F                    1       0.0206
# num_nonrel_judged_ret    1       68.0000
# num_q                    2       1.0000
# num_ret                  2       59.0000
# num_rel                  2       2.0000
# num_rel_ret              2       2.0000
# map                      2       0.5286
# gm_map                   2       -0.6376
# Rprec                    2       0.5000
# bpref                    2       0.5000
# recip_rank               2       1.0000
# iprec_at_recall_0.00     2       1.0000
# iprec_at_recall_0.10     2       1.0000
# iprec_at_recall_0.20     2       1.0000
# iprec_at_recall_0.30     2       1.0000
# iprec_at_recall_0.40     2       1.0000
# iprec_at_recall_0.50     2       1.0000
# iprec_at_recall_0.60     2       0.0571
# iprec_at_recall_0.70     2       0.0571
# iprec_at_recall_0.80     2       0.0571
# iprec_at_recall_0.90     2       0.0571
# iprec_at_recall_1.00     2       0.0571
# P_5                      2       0.2000
# P_10                     2       0.1000
# P_15                     2       0.0667
# P_20                     2       0.0500
# P_30                     2       0.0333
# P_100                    2       0.0200
# P_200                    2       0.0100
# P_500                    2       0.0040
# P_1000                   2       0.0020
# relstring                2       0.0000
# recall_5                 2       0.5000
# recall_10                2       0.5000
# recall_15                2       0.5000
# recall_20                2       0.5000
# recall_30                2       0.5000
# recall_100               2       1.0000
# recall_200               2       1.0000
# recall_500               2       1.0000
# recall_1000              2       1.0000
# infAP                    2       0.5286
# gm_bpref                 2       -0.6931
# Rprec_mult_0.20          2       1.0000
# Rprec_mult_0.40          2       1.0000
# Rprec_mult_0.60          2       0.5000
# Rprec_mult_0.80          2       0.5000
# Rprec_mult_1.00          2       0.5000
# Rprec_mult_1.20          2       0.3333
# Rprec_mult_1.40          2       0.3333
# Rprec_mult_1.60          2       0.2500
# Rprec_mult_1.80          2       0.2500
# Rprec_mult_2.00          2       0.2500
# utility                  2       -55.0000
# 11pt_avg                 2       0.5714
# binG                     2       0.5975
# G                        2       0.5975
# ndcg                     2       0.7317
# ndcg_rel                 2       0.8659
# Rndcg                    2       0.6724
# ndcg_cut_5               2       0.6131
# ndcg_cut_10              2       0.6131
# ndcg_cut_15              2       0.6131
# ndcg_cut_20              2       0.6131
# ndcg_cut_30              2       0.6131
# ndcg_cut_100             2       0.7317
# ndcg_cut_200             2       0.7317
# ndcg_cut_500             2       0.7317
# ndcg_cut_1000            2       0.7317
# map_cut_5                2       0.5000
# map_cut_10               2       0.5000
# map_cut_15               2       0.5000
# map_cut_20               2       0.5000
# map_cut_30               2       0.5000
# map_cut_100              2       0.5286
# map_cut_200              2       0.5286
# map_cut_500              2       0.5286
# map_cut_1000             2       0.5286
# relative_P_5             2       0.5000
# relative_P_10            2       0.5000
# relative_P_15            2       0.5000
# relative_P_20            2       0.5000
# relative_P_30            2       0.5000
# relative_P_100           2       1.0000
# relative_P_200           2       1.0000
# relative_P_500           2       1.0000
# relative_P_1000          2       1.0000
# success_1                2       1.0000
# success_5                2       1.0000
# success_10               2       1.0000
# set_P                    2       0.0339
# set_relative_P           2       1.0000
# set_recall               2       1.0000
# set_map                  2       0.0339
# set_F                    2       0.0656
# num_nonrel_judged_ret    2       28.0000
# num_q                    4       1.0000
# num_ret                  4       902.0000
# num_rel                  4       4.0000
# num_rel_ret              4       4.0000
# map                      4       0.5516
# gm_map                   4       -0.5950
# Rprec                    4       0.5000
# bpref                    4       0.5000
# recip_rank               4       1.0000
# iprec_at_recall_0.00     4       1.0000
# iprec_at_recall_0.10     4       1.0000
# iprec_at_recall_0.20     4       1.0000
# iprec_at_recall_0.30     4       1.0000
# iprec_at_recall_0.40     4       1.0000
# iprec_at_recall_0.50     4       1.0000
# iprec_at_recall_0.60     4       0.1154
# iprec_at_recall_0.70     4       0.1154
# iprec_at_recall_0.80     4       0.0909
# iprec_at_recall_0.90     4       0.0909
# iprec_at_recall_1.00     4       0.0909
# P_5                      4       0.4000
# P_10                     4       0.2000
# P_15                     4       0.1333
# P_20                     4       0.1000
# P_30                     4       0.1000
# P_100                    4       0.0400
# P_200                    4       0.0200
# P_500                    4       0.0080
# P_1000                   4       0.0040
# relstring                4       0.0000
# recall_5                 4       0.5000
# recall_10                4       0.5000
# recall_15                4       0.5000
# recall_20                4       0.5000
# recall_30                4       0.7500
# recall_100               4       1.0000
# recall_200               4       1.0000
# recall_500               4       1.0000
# recall_1000              4       1.0000
# infAP                    4       0.5516
# gm_bpref                 4       -0.6931
# Rprec_mult_0.20          4       1.0000
# Rprec_mult_0.40          4       1.0000
# Rprec_mult_0.60          4       0.6667
# Rprec_mult_0.80          4       0.5000
# Rprec_mult_1.00          4       0.5000
# Rprec_mult_1.20          4       0.4000
# Rprec_mult_1.40          4       0.3333
# Rprec_mult_1.60          4       0.2857
# Rprec_mult_1.80          4       0.2500
# Rprec_mult_2.00          4       0.2500
# utility                  4       -894.0000
# 11pt_avg                 4       0.5912
# binG                     4       0.6002
# G                        4       0.6002
# ndcg                     4       0.7899
# ndcg_rel                 4       0.8772
# Rndcg                    4       0.7133
# ndcg_cut_5               4       0.6367
# ndcg_cut_10              4       0.6367
# ndcg_cut_15              4       0.6367
# ndcg_cut_20              4       0.6367
# ndcg_cut_30              4       0.7188
# ndcg_cut_100             4       0.7899
# ndcg_cut_200             4       0.7899
# ndcg_cut_500             4       0.7899
# ndcg_cut_1000            4       0.7899
# map_cut_5                4       0.5000
# map_cut_10               4       0.5000
# map_cut_15               4       0.5000
# map_cut_20               4       0.5000
# map_cut_30               4       0.5288
# map_cut_100              4       0.5516
# map_cut_200              4       0.5516
# map_cut_500              4       0.5516
# map_cut_1000             4       0.5516
# relative_P_5             4       0.5000
# relative_P_10            4       0.5000
# relative_P_15            4       0.5000
# relative_P_20            4       0.5000
# relative_P_30            4       0.7500
# relative_P_100           4       1.0000
# relative_P_200           4       1.0000
# relative_P_500           4       1.0000
# relative_P_1000          4       1.0000
# success_1                4       1.0000
# success_5                4       1.0000
# success_10               4       1.0000
# set_P                    4       0.0044
# set_relative_P           4       1.0000
# set_recall               4       1.0000
# set_map                  4       0.0044
# set_F                    4       0.0088
# num_nonrel_judged_ret    4       76.0000
# num_q                    6       1.0000
# num_ret                  6       450.0000
# num_rel                  6       1.0000
# num_rel_ret              6       1.0000
# map                      6       0.0250
# gm_map                   6       -3.6889
# Rprec                    6       0.0000
# bpref                    6       0.0000
# recip_rank               6       0.0250
# iprec_at_recall_0.00     6       0.0250
# iprec_at_recall_0.10     6       0.0250
# iprec_at_recall_0.20     6       0.0250
# iprec_at_recall_0.30     6       0.0250
# iprec_at_recall_0.40     6       0.0250
# iprec_at_recall_0.50     6       0.0250
# iprec_at_recall_0.60     6       0.0250
# iprec_at_recall_0.70     6       0.0250
# iprec_at_recall_0.80     6       0.0250
# iprec_at_recall_0.90     6       0.0250
# iprec_at_recall_1.00     6       0.0250
# P_5                      6       0.0000
# P_10                     6       0.0000
# P_15                     6       0.0000
# P_20                     6       0.0000
# P_30                     6       0.0000
# P_100                    6       0.0100
# P_200                    6       0.0050
# P_500                    6       0.0020
# P_1000                   6       0.0010
# relstring                6       0.0000
# recall_5                 6       0.0000
# recall_10                6       0.0000
# recall_15                6       0.0000
# recall_20                6       0.0000
# recall_30                6       0.0000
# recall_100               6       1.0000
# recall_200               6       1.0000
# recall_500               6       1.0000
# recall_1000              6       1.0000
# infAP                    6       0.0250
# gm_bpref                 6       -11.5129
# Rprec_mult_0.20          6       0.0000
# Rprec_mult_0.40          6       0.0000
# Rprec_mult_0.60          6       0.0000
# Rprec_mult_0.80          6       0.0000
# Rprec_mult_1.00          6       0.0000
# Rprec_mult_1.20          6       0.0000
# Rprec_mult_1.40          6       0.0000
# Rprec_mult_1.60          6       0.0000
# Rprec_mult_1.80          6       0.0000
# Rprec_mult_2.00          6       0.0000
# utility                  6       -448.0000
# 11pt_avg                 6       0.0250
# binG                     6       0.1867
# G                        6       0.1867
# ndcg                     6       0.1867
# ndcg_rel                 6       0.1867
# Rndcg                    6       0.0933
# ndcg_cut_5               6       0.0000
# ndcg_cut_10              6       0.0000
# ndcg_cut_15              6       0.0000
# ndcg_cut_20              6       0.0000
# ndcg_cut_30              6       0.0000
# ndcg_cut_100             6       0.1867
# ndcg_cut_200             6       0.1867
# ndcg_cut_500             6       0.1867
# ndcg_cut_1000            6       0.1867
# map_cut_5                6       0.0000
# map_cut_10               6       0.0000
# map_cut_15               6       0.0000
# map_cut_20               6       0.0000
# map_cut_30               6       0.0000
# map_cut_100              6       0.0250
# map_cut_200              6       0.0250
# map_cut_500              6       0.0250
# map_cut_1000             6       0.0250
# relative_P_5             6       0.0000
# relative_P_10            6       0.0000
# relative_P_15            6       0.0000
# relative_P_20            6       0.0000
# relative_P_30            6       0.0000
# relative_P_100           6       1.0000
# relative_P_200           6       1.0000
# relative_P_500           6       1.0000
# relative_P_1000          6       1.0000
# success_1                6       0.0000
# success_5                6       0.0000
# success_10               6       0.0000
# set_P                    6       0.0022
# set_relative_P           6       1.0000
# set_recall               6       1.0000
# set_map                  6       0.0022
# set_F                    6       0.0044
# num_nonrel_judged_ret    6       93.0000
# num_q                    7       1.0000
# num_ret                  7       416.0000
# num_rel                  7       3.0000
# num_rel_ret              7       2.0000
# map                      7       0.2167
# gm_map                   7       -1.5294
# Rprec                    7       0.0000
# bpref                    7       0.0000
# recip_rank               7       0.2500
# iprec_at_recall_0.00     7       0.4000
# iprec_at_recall_0.10     7       0.4000
# iprec_at_recall_0.20     7       0.4000
# iprec_at_recall_0.30     7       0.4000
# iprec_at_recall_0.40     7       0.4000
# iprec_at_recall_0.50     7       0.4000
# iprec_at_recall_0.60     7       0.4000
# iprec_at_recall_0.70     7       0.4000
# iprec_at_recall_0.80     7       0.0000
# iprec_at_recall_0.90     7       0.0000
# iprec_at_recall_1.00     7       0.0000
# P_5                      7       0.4000
# P_10                     7       0.2000
# P_15                     7       0.1333
# P_20                     7       0.1000
# P_30                     7       0.0667
# P_100                    7       0.0200
# P_200                    7       0.0100
# P_500                    7       0.0040
# P_1000                   7       0.0020
# relstring                7       0.0000
# recall_5                 7       0.6667
# recall_10                7       0.6667
# recall_15                7       0.6667
# recall_20                7       0.6667
# recall_30                7       0.6667
# recall_100               7       0.6667
# recall_200               7       0.6667
# recall_500               7       0.6667
# recall_1000              7       0.6667
# infAP                    7       0.2167
# gm_bpref                 7       -11.5129
# Rprec_mult_0.20          7       0.0000
# Rprec_mult_0.40          7       0.0000
# Rprec_mult_0.60          7       0.0000
# Rprec_mult_0.80          7       0.0000
# Rprec_mult_1.00          7       0.0000
# Rprec_mult_1.20          7       0.2500
# Rprec_mult_1.40          7       0.4000
# Rprec_mult_1.60          7       0.4000
# Rprec_mult_1.80          7       0.3333
# Rprec_mult_2.00          7       0.3333
# utility                  7       -412.0000
# 11pt_avg                 7       0.2909
# binG                     7       0.2871
# G                        7       0.2871
# ndcg                     7       0.3836
# ndcg_rel                 7       0.3231
# Rndcg                    7       0.1918
# ndcg_cut_5               7       0.3836
# ndcg_cut_10              7       0.3836
# ndcg_cut_15              7       0.3836
# ndcg_cut_20              7       0.3836
# ndcg_cut_30              7       0.3836
# ndcg_cut_100             7       0.3836
# ndcg_cut_200             7       0.3836
# ndcg_cut_500             7       0.3836
# ndcg_cut_1000            7       0.3836
# map_cut_5                7       0.2167
# map_cut_10               7       0.2167
# map_cut_15               7       0.2167
# map_cut_20               7       0.2167
# map_cut_30               7       0.2167
# map_cut_100              7       0.2167
# map_cut_200              7       0.2167
# map_cut_500              7       0.2167
# map_cut_1000             7       0.2167
# relative_P_5             7       0.6667
# relative_P_10            7       0.6667
# relative_P_15            7       0.6667
# relative_P_20            7       0.6667
# relative_P_30            7       0.6667
# relative_P_100           7       0.6667
# relative_P_200           7       0.6667
# relative_P_500           7       0.6667
# relative_P_1000          7       0.6667
# success_1                7       0.0000
# success_5                7       1.0000
# success_10               7       1.0000
# set_P                    7       0.0048
# set_relative_P           7       0.6667
# set_recall               7       0.6667
# set_map                  7       0.0032
# set_F                    7       0.0095
# num_nonrel_judged_ret    7       93.0000
# num_q                    9       1.0000
# num_ret                  9       1856.0000
# num_rel                  9       1.0000
# num_rel_ret              9       1.0000
# map                      9       0.2500
# gm_map                   9       -1.3863
# Rprec                    9       0.0000
# bpref                    9       0.0000
# recip_rank               9       0.2500
# iprec_at_recall_0.00     9       0.2500
# iprec_at_recall_0.10     9       0.2500
# iprec_at_recall_0.20     9       0.2500
# iprec_at_recall_0.30     9       0.2500
# iprec_at_recall_0.40     9       0.2500
# iprec_at_recall_0.50     9       0.2500
# iprec_at_recall_0.60     9       0.2500
# iprec_at_recall_0.70     9       0.2500
# iprec_at_recall_0.80     9       0.2500
# iprec_at_recall_0.90     9       0.2500
# iprec_at_recall_1.00     9       0.2500
# P_5                      9       0.2000
# P_10                     9       0.1000
# P_15                     9       0.0667
# P_20                     9       0.0500
# P_30                     9       0.0333
# P_100                    9       0.0100
# P_200                    9       0.0050
# P_500                    9       0.0020
# P_1000                   9       0.0010
# relstring                9       0.0000
# recall_5                 9       1.0000
# recall_10                9       1.0000
# recall_15                9       1.0000
# recall_20                9       1.0000
# recall_30                9       1.0000
# recall_100               9       1.0000
# recall_200               9       1.0000
# recall_500               9       1.0000
# recall_1000              9       1.0000
# infAP                    9       0.2500
# gm_bpref                 9       -11.5129
# Rprec_mult_0.20          9       0.0000
# Rprec_mult_0.40          9       0.0000
# Rprec_mult_0.60          9       0.0000
# Rprec_mult_0.80          9       0.0000
# Rprec_mult_1.00          9       0.0000
# Rprec_mult_1.20          9       0.0000
# Rprec_mult_1.40          9       0.0000
# Rprec_mult_1.60          9       0.0000
# Rprec_mult_1.80          9       0.0000
# Rprec_mult_2.00          9       0.0000
# utility                  9       -1854.0000
# 11pt_avg                 9       0.2500
# binG                     9       0.4307
# G                        9       0.4307
# ndcg                     9       0.4307
# ndcg_rel                 9       0.4307
# Rndcg                    9       0.2153
# ndcg_cut_5               9       0.4307
# ndcg_cut_10              9       0.4307
# ndcg_cut_15              9       0.4307
# ndcg_cut_20              9       0.4307
# ndcg_cut_30              9       0.4307
# ndcg_cut_100             9       0.4307
# ndcg_cut_200             9       0.4307
# ndcg_cut_500             9       0.4307
# ndcg_cut_1000            9       0.4307
# map_cut_5                9       0.2500
# map_cut_10               9       0.2500
# map_cut_15               9       0.2500
# map_cut_20               9       0.2500
# map_cut_30               9       0.2500
# map_cut_100              9       0.2500
# map_cut_200              9       0.2500
# map_cut_500              9       0.2500
# map_cut_1000             9       0.2500
# relative_P_5             9       1.0000
# relative_P_10            9       1.0000
# relative_P_15            9       1.0000
# relative_P_20            9       1.0000
# relative_P_30            9       1.0000
# relative_P_100           9       1.0000
# relative_P_200           9       1.0000
# relative_P_500           9       1.0000
# relative_P_1000          9       1.0000
# success_1                9       0.0000
# success_5                9       1.0000
# success_10               9       1.0000
# set_P                    9       0.0005
# set_relative_P           9       1.0000
# set_recall               9       1.0000
# set_map                  9       0.0005
# set_F                    9       0.0011
# num_nonrel_judged_ret    9       170.0000
# num_q                    10      1.0000
# num_ret                  10      500.0000
# num_rel                  10      1.0000
# num_rel_ret              10      1.0000
# map                      10      0.3333
# gm_map                   10      -1.0986
# Rprec                    10      0.0000
# bpref                    10      0.0000
# recip_rank               10      0.3333
# iprec_at_recall_0.00     10      0.3333
# iprec_at_recall_0.10     10      0.3333
# iprec_at_recall_0.20     10      0.3333
# iprec_at_recall_0.30     10      0.3333
# iprec_at_recall_0.40     10      0.3333
# iprec_at_recall_0.50     10      0.3333
# iprec_at_recall_0.60     10      0.3333
# iprec_at_recall_0.70     10      0.3333
# iprec_at_recall_0.80     10      0.3333
# iprec_at_recall_0.90     10      0.3333
# iprec_at_recall_1.00     10      0.3333
# P_5                      10      0.2000
# P_10                     10      0.1000
# P_15                     10      0.0667
# P_20                     10      0.0500
# P_30                     10      0.0333
# P_100                    10      0.0100
# P_200                    10      0.0050
# P_500                    10      0.0020
# P_1000                   10      0.0010
# relstring                10      0.0000
# recall_5                 10      1.0000
# recall_10                10      1.0000
# recall_15                10      1.0000
# recall_20                10      1.0000
# recall_30                10      1.0000
# recall_100               10      1.0000
# recall_200               10      1.0000
# recall_500               10      1.0000
# recall_1000              10      1.0000
# infAP                    10      0.3333
# gm_bpref                 10      -11.5129
# Rprec_mult_0.20          10      0.0000
# Rprec_mult_0.40          10      0.0000
# Rprec_mult_0.60          10      0.0000
# Rprec_mult_0.80          10      0.0000
# Rprec_mult_1.00          10      0.0000
# Rprec_mult_1.20          10      0.0000
# Rprec_mult_1.40          10      0.0000
# Rprec_mult_1.60          10      0.0000
# Rprec_mult_1.80          10      0.0000
# Rprec_mult_2.00          10      0.0000
# utility                  10      -498.0000
# 11pt_avg                 10      0.3333
# binG                     10      0.5000
# G                        10      0.5000
# ndcg                     10      0.5000
# ndcg_rel                 10      0.5000
# Rndcg                    10      0.2500
# ndcg_cut_5               10      0.5000
# ndcg_cut_10              10      0.5000
# ndcg_cut_15              10      0.5000
# ndcg_cut_20              10      0.5000
# ndcg_cut_30              10      0.5000
# ndcg_cut_100             10      0.5000
# ndcg_cut_200             10      0.5000
# ndcg_cut_500             10      0.5000
# ndcg_cut_1000            10      0.5000
# map_cut_5                10      0.3333
# map_cut_10               10      0.3333
# map_cut_15               10      0.3333
# map_cut_20               10      0.3333
# map_cut_30               10      0.3333
# map_cut_100              10      0.3333
# map_cut_200              10      0.3333
# map_cut_500              10      0.3333
# map_cut_1000             10      0.3333
# relative_P_5             10      1.0000
# relative_P_10            10      1.0000
# relative_P_15            10      1.0000
# relative_P_20            10      1.0000
# relative_P_30            10      1.0000
# relative_P_100           10      1.0000
# relative_P_200           10      1.0000
# relative_P_500           10      1.0000
# relative_P_1000          10      1.0000
# success_1                10      0.0000
# success_5                10      1.0000
# success_10               10      1.0000
# set_P                    10      0.0020
# set_relative_P           10      1.0000
# set_recall               10      1.0000
# set_map                  10      0.0020
# set_F                    10      0.0040
# num_nonrel_judged_ret    10      82.0000
# num_q                    14      1.0000
# num_ret                  14      315.0000
# num_rel                  14      1.0000
# num_rel_ret              14      1.0000
# map                      14      1.0000
# gm_map                   14      0.0000
# Rprec                    14      1.0000
# bpref                    14      1.0000
# recip_rank               14      1.0000
# iprec_at_recall_0.00     14      1.0000
# iprec_at_recall_0.10     14      1.0000
# iprec_at_recall_0.20     14      1.0000
# iprec_at_recall_0.30     14      1.0000
# iprec_at_recall_0.40     14      1.0000
# iprec_at_recall_0.50     14      1.0000
# iprec_at_recall_0.60     14      1.0000
# iprec_at_recall_0.70     14      1.0000
# iprec_at_recall_0.80     14      1.0000
# iprec_at_recall_0.90     14      1.0000
# iprec_at_recall_1.00     14      1.0000
# P_5                      14      0.2000
# P_10                     14      0.1000
# P_15                     14      0.0667
# P_20                     14      0.0500
# P_30                     14      0.0333
# P_100                    14      0.0100
# P_200                    14      0.0050
# P_500                    14      0.0020
# P_1000                   14      0.0010
# relstring                14      0.0000
# recall_5                 14      1.0000
# recall_10                14      1.0000
# recall_15                14      1.0000
# recall_20                14      1.0000
# recall_30                14      1.0000
# recall_100               14      1.0000
# recall_200               14      1.0000
# recall_500               14      1.0000
# recall_1000              14      1.0000
# infAP                    14      1.0000
# gm_bpref                 14      0.0000
# Rprec_mult_0.20          14      1.0000
# Rprec_mult_0.40          14      1.0000
# Rprec_mult_0.60          14      1.0000
# Rprec_mult_0.80          14      1.0000
# Rprec_mult_1.00          14      1.0000
# Rprec_mult_1.20          14      0.5000
# Rprec_mult_1.40          14      0.5000
# Rprec_mult_1.60          14      0.5000
# Rprec_mult_1.80          14      0.5000
# Rprec_mult_2.00          14      0.5000
# utility                  14      -313.0000
# 11pt_avg                 14      1.0000
# binG                     14      1.0000
# G                        14      1.0000
# ndcg                     14      1.0000
# ndcg_rel                 14      1.0000
# Rndcg                    14      1.0000
# ndcg_cut_5               14      1.0000
# ndcg_cut_10              14      1.0000
# ndcg_cut_15              14      1.0000
# ndcg_cut_20              14      1.0000
# ndcg_cut_30              14      1.0000
# ndcg_cut_100             14      1.0000
# ndcg_cut_200             14      1.0000
# ndcg_cut_500             14      1.0000
# ndcg_cut_1000            14      1.0000
# map_cut_5                14      1.0000
# map_cut_10               14      1.0000
# map_cut_15               14      1.0000
# map_cut_20               14      1.0000
# map_cut_30               14      1.0000
# map_cut_100              14      1.0000
# map_cut_200              14      1.0000
# map_cut_500              14      1.0000
# map_cut_1000             14      1.0000
# relative_P_5             14      1.0000
# relative_P_10            14      1.0000
# relative_P_15            14      1.0000
# relative_P_20            14      1.0000
# relative_P_30            14      1.0000
# relative_P_100           14      1.0000
# relative_P_200           14      1.0000
# relative_P_500           14      1.0000
# relative_P_1000          14      1.0000
# success_1                14      1.0000
# success_5                14      1.0000
# success_10               14      1.0000
# set_P                    14      0.0032
# set_relative_P           14      1.0000
# set_recall               14      1.0000
# set_map                  14      0.0032
# set_F                    14      0.0063
# num_nonrel_judged_ret    14      101.0000
# num_q                    16      1.0000
# num_ret                  16      1111.0000
# num_rel                  16      7.0000
# num_rel_ret              16      7.0000
# map                      16      0.1709
# gm_map                   16      -1.7665
# Rprec                    16      0.1429
# bpref                    16      0.0204
# recip_rank               16      0.1429
# iprec_at_recall_0.00     16      0.2308
# iprec_at_recall_0.10     16      0.2308
# iprec_at_recall_0.20     16      0.2308
# iprec_at_recall_0.30     16      0.2308
# iprec_at_recall_0.40     16      0.2308
# iprec_at_recall_0.50     16      0.1852
# iprec_at_recall_0.60     16      0.1852
# iprec_at_recall_0.70     16      0.1852
# iprec_at_recall_0.80     16      0.1304
# iprec_at_recall_0.90     16      0.1250
# iprec_at_recall_1.00     16      0.1250
# P_5                      16      0.0000
# P_10                     16      0.2000
# P_15                     16      0.2000
# P_20                     16      0.1500
# P_30                     16      0.1667
# P_100                    16      0.0700
# P_200                    16      0.0350
# P_500                    16      0.0140
# P_1000                   16      0.0070
# relstring                16      0.0000
# recall_5                 16      0.0000
# recall_10                16      0.2857
# recall_15                16      0.4286
# recall_20                16      0.4286
# recall_30                16      0.7143
# recall_100               16      1.0000
# recall_200               16      1.0000
# recall_500               16      1.0000
# recall_1000              16      1.0000
# infAP                    16      0.1709
# gm_bpref                 16      -3.8918
# Rprec_mult_0.20          16      0.0000
# Rprec_mult_0.40          16      0.0000
# Rprec_mult_0.60          16      0.0000
# Rprec_mult_0.80          16      0.0000
# Rprec_mult_1.00          16      0.1429
# Rprec_mult_1.20          16      0.2222
# Rprec_mult_1.40          16      0.2000
# Rprec_mult_1.60          16      0.1667
# Rprec_mult_1.80          16      0.2308
# Rprec_mult_2.00          16      0.2143
# utility                  16      -1097.0000
# ndcg_cut_15              22      0.0000
# ndcg_cut_20              22      0.0000
# ndcg_cut_30              22      0.2211
# ndcg_cut_100             22      0.2211
# ndcg_cut_200             22      0.2211
# ndcg_cut_500             22      0.2211
# ndcg_cut_1000            22      0.2211
# map_cut_5                22      0.0000
# map_cut_10               22      0.0000
# map_cut_15               22      0.0000
# map_cut_20               22      0.0000
# map_cut_30               22      0.0455
# map_cut_100              22      0.0455
# map_cut_200              22      0.0455
# map_cut_500              22      0.0455
# map_cut_1000             22      0.0455
# relative_P_5             22      0.0000
# relative_P_10            22      0.0000
# relative_P_15            22      0.0000
# relative_P_20            22      0.0000
# relative_P_30            22      1.0000
# relative_P_100           22      1.0000
# relative_P_200           22      1.0000
# relative_P_500           22      1.0000
# relative_P_1000          22      1.0000
# success_1                22      0.0000
# success_5                22      0.0000
# success_10               22      0.0000
# set_P                    22      0.0021
# set_relative_P           22      1.0000
# set_recall               22      1.0000
# set_map                  22      0.0021
# set_F                    22      0.0043
# num_nonrel_judged_ret    22      128.0000
# num_q                    24      1.0000
# num_ret                  24      771.0000
# num_rel                  24      1.0000
# num_rel_ret              24      1.0000
# map                      24      1.0000
# gm_map                   24      0.0000
# Rprec                    24      1.0000
# bpref                    24      1.0000
# recip_rank               24      1.0000
# iprec_at_recall_0.00     24      1.0000
# iprec_at_recall_0.10     24      1.0000
# iprec_at_recall_0.20     24      1.0000
# iprec_at_recall_0.30     24      1.0000
# iprec_at_recall_0.40     24      1.0000
# iprec_at_recall_0.50     24      1.0000
# iprec_at_recall_0.60     24      1.0000
# iprec_at_recall_0.70     24      1.0000
# iprec_at_recall_0.80     24      1.0000
# iprec_at_recall_0.90     24      1.0000
# iprec_at_recall_1.00     24      1.0000
# P_5                      24      0.2000
# P_10                     24      0.1000
# P_15                     24      0.0667
# P_20                     24      0.0500
# P_30                     24      0.0333
# P_100                    24      0.0100
# P_200                    24      0.0050
# P_500                    24      0.0020
# P_1000                   24      0.0010
# relstring                24      0.0000
# recall_5                 24      1.0000
# recall_10                24      1.0000
# recall_15                24      1.0000
# recall_20                24      1.0000
# recall_30                24      1.0000
# recall_100               24      1.0000
# recall_200               24      1.0000
# recall_500               24      1.0000
# recall_1000              24      1.0000
# infAP                    24      1.0000
# gm_bpref                 24      0.0000
# Rprec_mult_0.20          24      1.0000
# Rprec_mult_0.40          24      1.0000
# Rprec_mult_0.60          24      1.0000
# Rprec_mult_0.80          24      1.0000
# Rprec_mult_1.00          24      1.0000
# Rprec_mult_1.20          24      0.5000
# Rprec_mult_1.40          24      0.5000
# Rprec_mult_1.60          24      0.5000
# Rprec_mult_1.80          24      0.5000
# Rprec_mult_2.00          24      0.5000
# utility                  24      -769.0000
# 11pt_avg                 24      1.0000
# binG                     24      1.0000
# G                        24      1.0000
# ndcg                     24      1.0000
# ndcg_rel                 24      1.0000
# Rndcg                    24      1.0000
# ndcg_cut_5               24      1.0000
# ndcg_cut_10              24      1.0000
# ndcg_cut_15              24      1.0000
# ndcg_cut_20              24      1.0000
# ndcg_cut_30              24      1.0000
# ndcg_cut_100             24      1.0000
# ndcg_cut_200             24      1.0000
# ndcg_cut_500             24      1.0000
# ndcg_cut_1000            24      1.0000
# map_cut_5                24      1.0000
# map_cut_10               24      1.0000
# map_cut_15               24      1.0000
# map_cut_20               24      1.0000
# map_cut_30               24      1.0000
# map_cut_100              24      1.0000
# map_cut_200              24      1.0000
# map_cut_500              24      1.0000
# map_cut_1000             24      1.0000
# relative_P_5             24      1.0000
# relative_P_10            24      1.0000
# relative_P_15            24      1.0000
# relative_P_20            24      1.0000
# relative_P_30            24      1.0000
# relative_P_100           24      1.0000
# relative_P_200           24      1.0000
# relative_P_500           24      1.0000
# relative_P_1000          24      1.0000
# success_1                24      1.0000
# success_5                24      1.0000
# success_10               24      1.0000
# set_P                    24      0.0013
# set_relative_P           24      1.0000
# set_recall               24      1.0000
# set_map                  24      0.0013
# set_F                    24      0.0026
# num_nonrel_judged_ret    24      122.0000
# num_q                    26      1.0000
# num_ret                  26      588.0000
# num_rel                  26      3.0000
# num_rel_ret              26      3.0000
# map                      26      0.0942
# gm_map                   26      -2.3620
# Rprec                    26      0.0000
# bpref                    26      0.0000
# recip_rank               26      0.1429
# iprec_at_recall_0.00     26      0.1429
# iprec_at_recall_0.10     26      0.1429
# iprec_at_recall_0.20     26      0.1429
# iprec_at_recall_0.30     26      0.1429
# iprec_at_recall_0.40     26      0.0732
# iprec_at_recall_0.50     26      0.0732
# iprec_at_recall_0.60     26      0.0732
# iprec_at_recall_0.70     26      0.0732
# iprec_at_recall_0.80     26      0.0732
# iprec_at_recall_0.90     26      0.0732
# iprec_at_recall_1.00     26      0.0732
# P_5                      26      0.0000
# P_10                     26      0.1000
# P_15                     26      0.0667
# P_20                     26      0.0500
# P_30                     26      0.0667
# P_100                    26      0.0300
# P_200                    26      0.0150
# P_500                    26      0.0060
# P_1000                   26      0.0030
# relstring                26      0.0000
# recall_5                 26      0.0000
# recall_10                26      0.3333
# recall_15                26      0.3333
# recall_20                26      0.3333
# recall_30                26      0.6667
# recall_100               26      1.0000
# recall_200               26      1.0000
# recall_500               26      1.0000
# recall_1000              26      1.0000
# infAP                    26      0.0942
# gm_bpref                 26      -11.5129
# Rprec_mult_0.20          26      0.0000
# Rprec_mult_0.40          26      0.0000
# Rprec_mult_0.60          26      0.0000
# Rprec_mult_0.80          26      0.0000
# Rprec_mult_1.00          26      0.0000
# Rprec_mult_1.20          26      0.0000
# Rprec_mult_1.40          26      0.0000
# Rprec_mult_1.60          26      0.0000
# Rprec_mult_1.80          26      0.0000
# Rprec_mult_2.00          26      0.0000
# utility                  26      -582.0000
# 11pt_avg                 26      0.0985
# binG                     26      0.2417
# G                        26      0.2417
# ndcg                     26      0.3382
# ndcg_rel                 26      0.2486
# Rndcg                    26      0.1691
# ndcg_cut_5               26      0.0000
# ndcg_cut_10              26      0.1564
# ndcg_cut_15              26      0.1564
# ndcg_cut_20              26      0.1564
# ndcg_cut_30              26      0.2511
# ndcg_cut_100             26      0.3382
# ndcg_cut_200             26      0.3382
# ndcg_cut_500             26      0.3382
# ndcg_cut_1000            26      0.3382
# map_cut_5                26      0.0000
# map_cut_10               26      0.0476
# map_cut_15               26      0.0476
# map_cut_20               26      0.0476
# map_cut_30               26      0.0698
# map_cut_100              26      0.0942
# map_cut_200              26      0.0942
# map_cut_500              26      0.0942
# map_cut_1000             26      0.0942
# relative_P_5             26      0.0000
# relative_P_10            26      0.3333
# relative_P_15            26      0.3333
# relative_P_20            26      0.3333
# relative_P_30            26      0.6667
# relative_P_100           26      1.0000
# relative_P_200           26      1.0000
# relative_P_500           26      1.0000
# relative_P_1000          26      1.0000
# success_1                26      0.0000
# success_5                26      0.0000
# success_10               26      1.0000
# set_P                    26      0.0051
# set_relative_P           26      1.0000
# set_recall               26      1.0000
# set_map                  26      0.0051
# set_F                    26      0.0102
# num_nonrel_judged_ret    26      115.0000
# num_q                    28      1.0000
# num_ret                  28      1267.0000
# num_rel                  28      2.0000
# num_rel_ret              28      2.0000
# map                      28      0.2250
# gm_map                   28      -1.4917
# Rprec                    28      0.0000
# bpref                    28      0.0000
# recip_rank               28      0.2000
# iprec_at_recall_0.00     28      0.2500
# iprec_at_recall_0.10     28      0.2500
# iprec_at_recall_0.20     28      0.2500
# iprec_at_recall_0.30     28      0.2500
# iprec_at_recall_0.40     28      0.2500
# iprec_at_recall_0.50     28      0.2500
# iprec_at_recall_0.60     28      0.2500
# iprec_at_recall_0.70     28      0.2500
# iprec_at_recall_0.80     28      0.2500
# iprec_at_recall_0.90     28      0.2500
# iprec_at_recall_1.00     28      0.2500
# P_5                      28      0.2000
# P_10                     28      0.2000
# P_15                     28      0.1333
# P_20                     28      0.1000
# P_30                     28      0.0667
# P_100                    28      0.0200
# P_200                    28      0.0100
# P_500                    28      0.0040
# P_1000                   28      0.0020
# relstring                28      0.0000
# recall_5                 28      0.5000
# recall_10                28      1.0000
# recall_15                28      1.0000
# recall_20                28      1.0000
# recall_30                28      1.0000
# recall_100               28      1.0000
# recall_200               28      1.0000
# recall_500               28      1.0000
# recall_1000              28      1.0000
# infAP                    28      0.2250
# gm_bpref                 28      -11.5129
# Rprec_mult_0.20          28      0.0000
# Rprec_mult_0.40          28      0.0000
# Rprec_mult_0.60          28      0.0000
# Rprec_mult_0.80          28      0.0000
# Rprec_mult_1.00          28      0.0000
# Rprec_mult_1.20          28      0.0000
# Rprec_mult_1.40          28      0.0000
# Rprec_mult_1.60          28      0.0000
# Rprec_mult_1.80          28      0.0000
# Rprec_mult_2.00          28      0.0000
# utility                  28      -1263.0000
# 11pt_avg                 28      0.2500
# binG                     28      0.3601
# G                        28      0.3601
# ndcg                     28      0.4306
# ndcg_rel                 28      0.3339
# Rndcg                    28      0.2153
# ndcg_cut_5               28      0.2372
# ndcg_cut_10              28      0.4306
# ndcg_cut_15              28      0.4306
# ndcg_cut_20              28      0.4306
# ndcg_cut_30              28      0.4306
# ndcg_cut_100             28      0.4306
# ndcg_cut_200             28      0.4306
# ndcg_cut_500             28      0.4306
# ndcg_cut_1000            28      0.4306
# map_cut_5                28      0.1000
# map_cut_10               28      0.2250
# map_cut_15               28      0.2250
# map_cut_20               28      0.2250
# map_cut_30               28      0.2250
# map_cut_100              28      0.2250
# map_cut_200              28      0.2250
# map_cut_500              28      0.2250
# map_cut_1000             28      0.2250
# relative_P_5             28      0.5000
# relative_P_10            28      1.0000
# relative_P_15            28      1.0000
# relative_P_20            28      1.0000
# relative_P_30            28      1.0000
# relative_P_100           28      1.0000
# relative_P_200           28      1.0000
# relative_P_500           28      1.0000
# relative_P_1000          28      1.0000
# success_1                28      0.0000
# success_5                28      1.0000
# success_10               28      1.0000
# set_P                    28      0.0016
# set_relative_P           28      1.0000
# set_recall               28      1.0000
# set_map                  28      0.0016
# set_F                    28      0.0032
# num_nonrel_judged_ret    28      107.0000
# num_q                    all     15.0000
# num_ret                  all     9844.0000
# num_rel                  all     35.0000
# num_rel_ret              all     33.0000
# map                      all     0.4002
# gm_map                   all     0.2447
# Rprec                    all     0.3095
# bpref                    all     0.3014
# recip_rank               all     0.4961
# iprec_at_recall_0.00     all     0.5187
# iprec_at_recall_0.10     all     0.5187
# iprec_at_recall_0.20     all     0.5187
# iprec_at_recall_0.30     all     0.5187
# iprec_at_recall_0.40     all     0.5141
# iprec_at_recall_0.50     all     0.5110
# iprec_at_recall_0.60     all     0.3225
# iprec_at_recall_0.70     all     0.3187
# iprec_at_recall_0.80     all     0.2867
# iprec_at_recall_0.90     all     0.2859
# iprec_at_recall_1.00     all     0.2859
# P_5                      all     0.1600
# P_10                     all     0.1067
# P_15                     all     0.0756
# P_20                     all     0.0600
# P_30                     all     0.0556
# P_100                    all     0.0213
# P_200                    all     0.0110
# P_500                    all     0.0044
# P_1000                   all     0.0022
# relstring                all     0.0000
# recall_5                 all     0.5111
# recall_10                all     0.5857
# recall_15                all     0.5952
# recall_20                all     0.6086
# recall_30                all     0.7598
# recall_100               all     0.9311
# recall_200               all     0.9444
# recall_500               all     0.9444
# recall_1000              all     0.9444
# infAP                    all     0.4002
# gm_bpref                 all     0.0014
# Rprec_mult_0.20          all     0.4000
# Rprec_mult_0.40          all     0.4000
# Rprec_mult_0.60          all     0.3111
# Rprec_mult_0.80          all     0.3000
# Rprec_mult_1.00          all     0.3095
# Rprec_mult_1.20          all     0.2026
# Rprec_mult_1.40          all     0.2067
# Rprec_mult_1.60          all     0.1902
# Rprec_mult_1.80          all     0.1876
# Rprec_mult_2.00          all     0.1865
# utility                  all     -651.8667
# 11pt_avg                 all     0.4182
# binG                     all     0.4907
# G                        all     0.4907
# ndcg                     all     0.5602
# ndcg_rel                 all     0.5529
# Rndcg                    all     0.4452
# ndcg_cut_5               all     0.4276
# ndcg_cut_10              all     0.4626
# ndcg_cut_15              all     0.4674
# ndcg_cut_20              all     0.4726
# ndcg_cut_30              all     0.5161
# ndcg_cut_100             all     0.5569
# ndcg_cut_200             all     0.5602
# ndcg_cut_500             all     0.5602
# ndcg_cut_1000            all     0.5602
# map_cut_5                all     0.3600
# map_cut_10               all     0.3750
# map_cut_15               all     0.3772
# map_cut_20               all     0.3779
# map_cut_30               all     0.3899
# map_cut_100              all     0.3997
# map_cut_200              all     0.4002
# map_cut_500              all     0.4002
# map_cut_1000             all     0.4002
# relative_P_5             all     0.5111
# relative_P_10            all     0.5857
# relative_P_15            all     0.5952
# relative_P_20            all     0.6086
# relative_P_30            all     0.7598
# relative_P_100           all     0.9311
# relative_P_200           all     0.9444
# relative_P_500           all     0.9444
# relative_P_1000          all     0.9444
# success_1                all     0.4000
# success_5                all     0.6667
# success_10               all     0.8000
# set_P                    all     0.0074
# set_relative_P           all     0.9444
# set_recall               all     0.9444
# set_map                  all     0.0072
# set_F                    all     0.0145
# num_nonrel_judged_ret    all     1383.0000

# %%
q4.print_rel_name('16')
# Out:
# ---------------------------Topic_id and Topic_phrase----------------------------------
# 16 Emergency and disaster preparedness assistance
# ---------------------------Return documents----------------------------------
# 16 Q0 G00-34-3591274 0 29.326098 test
# 16 Q0 G00-68-3661801 1 28.709376 test
# 16 Q0 G00-70-2681284 2 27.665278 test
# 16 Q0 G00-03-2245885 3 26.842133 test
# 16 Q0 G00-05-0719078 4 26.343186 test
# 16 Q0 G00-84-2647789 5 26.212271 test
# 16 Q0 G00-21-2114990 6 26.051207 test
# 16 Q0 G00-77-1693859 7 25.521510 test
# 16 Q0 G00-21-0494028 8 25.291854 test
# 16 Q0 G00-88-2853984 9 25.115507 test
# 16 Q0 G00-45-0006211 10 25.115507 test
# 16 Q0 G00-92-2053892 11 24.687331 test
# 16 Q0 G00-86-3719816 12 24.686965 test
# 16 Q0 G00-33-2857182 13 24.402549 test
# 16 Q0 G00-53-0263242 14 24.268069 test
# 16 Q0 G00-60-2564326 15 24.264838 test
# 16 Q0 G00-93-0870338 16 23.636041 test
# 16 Q0 G00-75-3633903 17 22.642157 test
# 16 Q0 G00-46-3010333 18 22.341671 test
# 16 Q0 G00-56-2140972 19 22.288811 test
# 16 Q0 G00-09-1393028 20 21.993189 test
# 16 Q0 G00-14-0931254 21 21.419573 test
# 16 Q0 G00-97-3418169 22 21.127327 test
# 16 Q0 G00-02-0866559 23 21.056377 test
# 16 Q0 G00-99-0140748 24 20.995558 test
# 16 Q0 G00-45-0028267 25 20.953786 test
# 16 Q0 G00-32-0551737 26 20.863211 test
# 16 Q0 G00-20-3839216 27 19.578542 test
# 16 Q0 G00-56-1706812 28 19.539221 test
# 16 Q0 G00-04-2858389 29 19.075580 test
# 16 Q0 G00-49-2630728 30 18.984148 test
# 16 Q0 G00-07-2244658 31 18.443876 test
# 16 Q0 G00-46-3492739 32 18.421429 test
# 16 Q0 G00-76-3480643 33 17.912180 test
# 16 Q0 G00-15-3335359 34 17.827536 test
# 16 Q0 G00-23-1010771 35 17.623540 test
# 16 Q0 G00-09-4172401 36 17.596569 test
# 16 Q0 G00-69-2828869 37 17.041954 test
# 16 Q0 G00-51-3264753 38 17.009987 test
# 16 Q0 G00-30-1702552 39 16.613288 test
# 16 Q0 G00-00-0503555 40 16.528743 test
# 16 Q0 G00-27-2669897 41 16.279360 test
# 16 Q0 G00-43-3607125 1101 0.992883 test
# 16 Q0 G00-91-3181951 1102 0.984930 test
# 16 Q0 G00-76-2323292 1103 0.966317 test
# 16 Q0 G00-79-2569923 1104 0.956085 test
# 16 Q0 G00-26-1962814 1105 0.948693 test
# 16 Q0 G00-25-1928405 1106 0.905229 test
# 16 Q0 G00-73-3170442 1107 0.901969 test
# 16 Q0 G00-33-0053624 1108 0.716119 test
# 16 Q0 G00-43-1143881 1109 0.694293 test
# 16 Q0 G00-60-0631416 1110 0.569974 test
# ---------------------------Relevant documents----------------------------------
# 16 0 G00-03-0589290 1
# 16 0 G00-21-0494028 1
# 16 0 G00-21-2114990 1
# 16 0 G00-32-0551737 1
# 16 0 G00-86-3719816 1
# 16 0 G00-92-2974327 1
# 16 0 G00-99-0140748 1

# %% [markdown]
# ### Q4 (b): Provide answer to Q4 (b) here [markdown cell]
#
# The modications I made and the resoaning for each is listed below:
#
# LowercaseFilter() - to get rid of distinction between upper and lower case letters in words
# IntraWordFilter() - to get rid of compound words connected by "-" "/" etc.
#
# StopFilter() - to get rid of common unimportant words like "and", "the" etc
#
# StripFilter() - to get rid of odd characters
#
# CustomFilter(LancasterStemmer().stem) - to return only the stem root of the words
#
# For query parser, changed the parser criteria from the defualt "and" to "orgroup"; this is because maybe not all the words in the topic would show up in the document, but the more words that show up the better still.
#
# For BM25 paramaters, I changed B to 0.5 and K1 to 1.9.
#
# I refeered to this website to understand how changing B and K impact the searches. https://www.elastic.co/blog/practical-bm25-part-2-the-bm25-algorithm-and-its-variables. I decided to decrease B to minimze the effects of the length of the document compared to the average length because the length of the government document does not matter that much to the relevance of the topic. I also decided to increase K1 to so that the score for each term can continue to go up by relatively more for more instances of that term.

# %% [markdown]
# ### Q4 (d): Provide answer to Q4 (c) here [markdown cell]
# Yes there is an improvement in the performance compared to question 3 and a significant improvement in performance compared to the baseline. It improved slightly from 0.35 in average map in Q3 to 0.40 in this section.

# %% [markdown]
# ## Validation

# %% [markdown]
# #### Run the following cells to make sure your code returns the correct value types

# %%
from whoosh.index import FileIndex
from whoosh.qparser import QueryParser
from whoosh.searching import Searcher
import os.path

# %% [markdown]
# ### Q2 Validation

# %%
assert(isinstance(q2.index_sys, FileIndex)), "Index Type"
assert(isinstance(q2.query_parser, QueryParser)), "Query Parser Type"
assert(isinstance(q2.searcher, Searcher)), "Searcher Type"
print("Q2 Types Validated")
# Out:
# Q2 Types Validated

# %% [markdown]
# ### Q3 Validation

# %%
assert(isinstance(q3.index_sys, FileIndex)), "Index Type"
assert(isinstance(q3.query_parser, QueryParser)), "Query Parser Type"
assert(isinstance(q3.searcher, Searcher)), "Searcher Type"
print("Q3 Types Validated")
# Out:
# Q3 Types Validated

# %% [markdown]
# ### Q4 Validation

# %%
assert(isinstance(q4.index_sys, FileIndex)), "Index Type"
assert(isinstance(q4.query_parser, QueryParser)), "Query Parser Type"
assert(isinstance(q4.searcher, Searcher)), "Searcher Type"
print("Q4 Types Validated")
# Out:
# Q4 Types Validated
